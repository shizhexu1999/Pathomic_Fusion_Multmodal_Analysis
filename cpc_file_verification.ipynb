# %% [markdown]
# ## The .pt files in `all_st_cpc` folder

# %%
import os
import torch
from torch_geometric.data import Data

directory = "data/TCGA_GBMLGG/all_st_cpc"

correct_edge_index_count = 0

# iterate through each file in the directory
for filename in os.listdir(directory):
    if filename.endswith(".pt"):
        filepath = os.path.join(directory, filename)

        data = torch.load(filepath)

        num_nodes = data.num_nodes
        max_edge_index = data.edge_index.max().item()

        if max_edge_index >= num_nodes:
            print(
                f"In file {filename}, edge_index max ({max_edge_index}) is greater than or equal to the number of nodes ({num_nodes})."
            )
        else:
            correct_edge_index_count += 1
            print(f"In file {filename}, edge_index is correctly defined")

print(f"Correct edge_index count: {correct_edge_index_count}")
# Out:
# In file TCGA-HT-7481-01Z-00-DX4.C8D1B102-5254-431F-9A10-BB1DF1DFDF40_1.pt, edge_index is correctly defined
# In file TCGA-06-0154-01Z-00-DX2.5d908d2e-08ba-4ae0-bb0e-34472a5ed4b3_2.pt, edge_index is correctly defined
# In file TCGA-06-0147-01Z-00-DX2.57e3c7a3-b271-4ab3-b6a0-aac29f5d52a6_2.pt, edge_index is correctly defined
# In file TCGA-FG-A60K-01Z-00-DX1.A5997F67-B39A-477A-BE71-BF72FD9596F8_2.pt, edge_index is correctly defined
# In file TCGA-06-5859-01Z-00-DX1.ab40e405-f25a-4fd2-95a2-ed86f8a2007f_1.pt, edge_index is correctly defined
# In file TCGA-CS-6290-01Z-00-DX1.BA4C9FC2-DD06-45F4-A7D2-5B3230DF027C_1.pt, edge_index is correctly defined
# In file TCGA-HW-7491-01Z-00-DX1.0648acf5-5dbd-47ad-96fd-52d765398718_2.pt, edge_index is correctly defined
# In file TCGA-14-1037-01Z-00-DX1.4a7c2db6-d389-4194-ac24-8a739c68c7f3_2.pt, edge_index is correctly defined
# In file TCGA-14-1453-01Z-00-DX4.023ea4a4-364c-4785-af1c-16e580cda290_1.pt, edge_index is correctly defined
# In file TCGA-19-2619-01Z-00-DX1.ed7e1a51-2352-4162-81f2-4a3b3bdab22c_1.pt, edge_index is correctly defined
# In file TCGA-06-0190-01Z-00-DX1.84da294a-81f2-4820-b72e-f084769f771a_1.pt, edge_index is correctly defined
# In file TCGA-08-0351-01Z-00-DX1.F5C2AE7A-1BD1-407A-B615-AA2EE331483E_1.pt, edge_index is correctly defined
# In file TCGA-RY-A840-01Z-00-DX1.E4D70B62-E2F7-411D-A9A8-DD78C20DF6B8_1.pt, edge_index is correctly defined
# In file TCGA-08-0520-01Z-00-DX1.2d50b1bc-c1d8-41a4-b42f-19d9916a5ef6_1.pt, edge_index is correctly defined
# In file TCGA-27-2523-01Z-00-DX1.5DD91AEC-7050-4DDC-8B59-57006E7B9006_2.pt, edge_index is correctly defined
# In file TCGA-FG-5962-01Z-00-DX1.3df4ee8a-9be3-482e-a0d6-4e4d9c3c9f54_2.pt, edge_index is correctly defined
# In file TCGA-02-0325-01Z-00-DX1.a1fc7539-5c33-494a-b3b3-41576a164c95_2.pt, edge_index is correctly defined
# In file TCGA-FG-8188-01Z-00-DX2.41b9a28a-95c5-4ebe-ab98-51aa44967cd0_1.pt, edge_index is correctly defined
# In file TCGA-FG-A87Q-01Z-00-DX1.FF3D3CFD-BBF1-42F4-8CEA-CF06A2CC451B_2.pt, edge_index is correctly defined
# In file TCGA-02-0258-01Z-00-DX1.826e828e-c9d6-4154-8244-9601f8149699_1.pt, edge_index is correctly defined
# In file TCGA-DB-5277-01Z-00-DX2.F1B46E37-AC7F-4805-9606-468744147AF8_1.pt, edge_index is correctly defined
# In file TCGA-27-1833-01Z-00-DX2.152a5b4b-2a73-49f2-af6f-84bf292241a3_2.pt, edge_index is correctly defined
# In file TCGA-DB-A64V-01Z-00-DX1.F6D441CA-6613-4F91-9E54-0FBB3F17CE08_2.pt, edge_index is correctly defined
# In file TCGA-DB-A4XH-01Z-00-DX2.2F6F5DB6-0C6E-4D20-9B72-BB274583DFFB_1.pt, edge_index is correctly defined
# In file TCGA-FG-8187-01Z-00-DX2.e9ba4a17-f5b7-4786-b4f3-29e0d79b5985_1.pt, edge_index is correctly defined
# In file TCGA-WY-A85C-01Z-00-DX1.E0A6429A-91B3-4FFE-9FF9-28D956864D24_1.pt, edge_index is correctly defined
# In file TCGA-06-0744-01Z-00-DX1.948cea15-dbea-483c-becb-78166086ec0a_1.pt, edge_index is correctly defined
# In file TCGA-06-0166-01Z-00-DX1.f0c10e84-1591-4ac1-9d14-0eb468f155f1_2.pt, edge_index is correctly defined
# In file TCGA-HT-7686-01Z-00-DX1.BBFB6833-AB78-4B58-B996-20A0D57C7713_2.pt, edge_index is correctly defined
# In file TCGA-HT-7680-01Z-00-DX1.112866BF-8B2F-4007-8F61-FACFC66CDA6C_1.pt, edge_index is correctly defined
# In file TCGA-DU-7006-01Z-00-DX1.F91BD282-C5E5-441D-806E-354A1F78B04F_1.pt, edge_index is correctly defined
# In file TCGA-DH-A7US-01Z-00-DX1.0CC50064-5604-449F-8A97-860436784030_2.pt, edge_index is correctly defined
# In file TCGA-06-0143-01Z-00-DX2.6c4cb4fb-440c-4099-b7db-ff863614c9b8_2.pt, edge_index is correctly defined
# In file TCGA-02-0006-01Z-00-DX1.a37df719-8b93-4245-ae49-67eb1114253a_1.pt, edge_index is correctly defined
# In file TCGA-27-2518-01Z-00-DX1.148935FE-8C0A-4168-9D62-6AFF31DB75CE_1.pt, edge_index is correctly defined
# In file TCGA-R8-A6MO-01Z-00-DXB.874632D2-DD16-441A-927D-DF54C5ED35F2_1.pt, edge_index is correctly defined
# In file TCGA-14-1452-01Z-00-DX2.0a482b56-e322-488c-af00-492a7d41caeb_2.pt, edge_index is correctly defined
# In file TCGA-06-5858-01Z-00-DX1.d964971f-f75f-478a-bc85-10a510bd2835_1.pt, edge_index is correctly defined
# In file TCGA-08-0390-01Z-00-DX1.01310651-CD52-4244-8C13-44001BBAC17E_2.pt, edge_index is correctly defined
# In file TCGA-27-1832-01Z-00-DX2.ca89e95e-bfec-4d59-9948-fa3698b93f08_1.pt, edge_index is correctly defined
# In file TCGA-FG-6692-01Z-00-DX1.719e6a21-c620-46a4-a47e-fb0fccc34cec_1.pt, edge_index is correctly defined
# In file TCGA-S9-A6WP-01Z-00-DX1.C3E303DF-A88E-4A62-8958-BDE01A384D99_1.pt, edge_index is correctly defined
# In file TCGA-HT-7481-01Z-00-DX3.A8785012-CACE-4B56-8B1F-07AA96B00D1D_2.pt, edge_index is correctly defined
# In file TCGA-F6-A8O3-01Z-00-DX1.64B49CF2-4626-48BE-88B5-646E0BDF520C_1.pt, edge_index is correctly defined
# In file TCGA-06-1801-01Z-00-DX1.94958ef7-74a5-415e-bd4c-a4e52e1f6551_2.pt, edge_index is correctly defined
# In file TCGA-S9-A89Z-01Z-00-DX1.F6DA547D-D35C-4D55-B5AA-AB4F33B2789F_1.pt, edge_index is correctly defined
# In file TCGA-HT-7677-01Z-00-DX3.357F25D7-5314-4EE2-A7A0-CF28742EDB0E_2.pt, edge_index is correctly defined
# In file TCGA-HT-A74K-01Z-00-DX1.D1FB878B-4562-45A9-ACB1-FAAB8EA24EF7_1.pt, edge_index is correctly defined
# In file TCGA-08-0525-01Z-00-DX1.254e63b9-3979-41d6-af5d-fb7bf1a9606f_2.pt, edge_index is correctly defined
# In file TCGA-DH-A66G-01Z-00-DX1.82A4242B-EAB4-4474-B5C9-27FD5C322201_1.pt, edge_index is correctly defined
# In file TCGA-HT-A61B-01Z-00-DX1.4D520756-D42C-480F-B13A-E2D6B4421668_1.pt, edge_index is correctly defined
# In file TCGA-06-0184-01Z-00-DX2.b2242e9f-fac3-4e80-a82c-413e32332b68_2.pt, edge_index is correctly defined
# In file TCGA-02-0015-01Z-00-DX1.73c07790-a054-4725-b123-4f09a2de961a_3.pt, edge_index is correctly defined
# In file TCGA-02-0009-01Z-00-DX2.f5c99ad0-30b1-4f1b-afb0-0a355068eacc_1.pt, edge_index is correctly defined
# In file TCGA-DB-A4XC-01Z-00-DX1.5768EC5F-D8B2-47B3-A685-059792C8751E_1.pt, edge_index is correctly defined
# In file TCGA-HW-7495-01Z-00-DX1.6453ae00-7849-4b90-ac8f-fd32791d21b1_1.pt, edge_index is correctly defined
# In file TCGA-FG-8191-01Z-00-DX1.cf5a8abc-ba6d-438f-b070-95fc79ba0fce_1.pt, edge_index is correctly defined
# In file TCGA-FG-A4MY-01Z-00-DX1.EB81EFA3-9B05-4480-8570-8D16B923D655_1.pt, edge_index is correctly defined
# In file TCGA-06-0143-01Z-00-DX3.e9011249-11f6-454b-98f1-7f2bcfea228c_1.pt, edge_index is correctly defined
# In file TCGA-12-0618-01Z-00-DX1.e174afd8-0708-4e92-8c4b-9578062e56ea_2.pt, edge_index is correctly defined
# In file TCGA-FG-A87Q-01Z-00-DX2.28565DCA-8540-4461-87A4-489A0411DAF2_1.pt, edge_index is correctly defined
# In file TCGA-08-0345-01Z-00-DX1.DEC032EE-E0D3-4F8A-9008-063BDC17DFBF_2.pt, edge_index is correctly defined
# In file TCGA-QH-A6CV-01Z-00-DX1.9DCB8BF5-AE89-4D03-9892-F689B41320D0_1.pt, edge_index is correctly defined
# In file TCGA-19-A6J5-01Z-00-DX1.2667B32C-FDF4-4197-BD32-56D6124BD01C_2.pt, edge_index is correctly defined
# In file TCGA-OX-A56R-01Z-00-DX1.6AC88CAE-73F3-4ECF-AE06-E347574EB6E8_2.pt, edge_index is correctly defined
# In file TCGA-HT-8012-01Z-00-DX1.6437C769-CD18-4DC2-8961-1E2C89018045_1.pt, edge_index is correctly defined
# In file TCGA-HT-7609-01Z-00-DX3.D3050BBE-3F54-4662-9867-608D69759599_2.pt, edge_index is correctly defined
# In file TCGA-14-1825-01Z-00-DX1.f09203b7-73b2-4600-a92e-b097508b86ba_2.pt, edge_index is correctly defined
# In file TCGA-VM-A8CD-01Z-00-DX3.E93E4734-17DD-40F9-AE98-3E2146E6F9F8_1.pt, edge_index is correctly defined
# In file TCGA-HT-7467-01Z-00-DX4.2CD993E3-7E94-4152-952F-4B12AB4F5EF7_1.pt, edge_index is correctly defined
# In file TCGA-DU-8166-01Z-00-DX1.82951397-8c63-4c0f-8696-f081b170e21f_1.pt, edge_index is correctly defined
# In file TCGA-TM-A84M-01Z-00-DX2.D73D0E2C-59B4-400F-B8DE-B49BACC45D26_1.pt, edge_index is correctly defined
# In file TCGA-08-0245-01Z-00-DX1.CFCAFA75-E128-47D9-9F16-43A175738145_2.pt, edge_index is correctly defined
# In file TCGA-02-0085-01Z-00-DX1.ac1b3db0-1647-4303-9a95-d67fab6bf700_2.pt, edge_index is correctly defined
# In file TCGA-19-1387-01Z-00-DX1.fd111d54-f1da-4ab9-8104-1f73c72808a8_1.pt, edge_index is correctly defined
# In file TCGA-06-0157-01Z-00-DX1.0bb9c6aa-3a9c-4d2b-9ce6-9a1cf54882a4_1.pt, edge_index is correctly defined
# In file TCGA-S9-A7J1-01Z-00-DX1.E6934DF9-A2DF-4454-B927-CD481786EB3A_2.pt, edge_index is correctly defined
# In file TCGA-14-1451-01Z-00-DX1.e97169f1-5aa9-41f1-9780-349d5744bfae_2.pt, edge_index is correctly defined
# In file TCGA-02-0034-01Z-00-DX2.f86120e8-3574-4a1d-a42b-248e86e2674f_1.pt, edge_index is correctly defined
# In file TCGA-06-5417-01Z-00-DX1.bf70952e-fdb5-4d0a-b0c1-2823e908f599_2.pt, edge_index is correctly defined
# In file TCGA-DB-A64W-01Z-00-DX1.25848BE9-A940-4827-88AA-555527EB81AA_1.pt, edge_index is correctly defined
# In file TCGA-DU-5855-01Z-00-DX1.046a8964-3cdf-49cf-a65c-3254e50ae90d_1.pt, edge_index is correctly defined
# In file TCGA-TM-A7CF-02Z-00-DX1.7EFCCDDE-B065-4367-8C0B-91A3D4E277D5_1.pt, edge_index is correctly defined
# In file TCGA-IK-8125-01Z-00-DX1.1491FC08-FB5D-4697-9A8C-9172FAF63C1C_1.pt, edge_index is correctly defined
# In file TCGA-HT-7881-01Z-00-DX2.B2794A3E-1243-4816-99C2-215F6521774D_1.pt, edge_index is correctly defined
# In file TCGA-VM-A8CE-01Z-00-DX8.94355113-F8C2-401E-988C-B3112B054186_1.pt, edge_index is correctly defined
# In file TCGA-TM-A7C4-01Z-00-DX1.082C7A0D-CCAA-4D40-B7B5-1CDD1812DF57_1.pt, edge_index is correctly defined
# In file TCGA-08-0357-01Z-00-DX1.F0E652B4-DE1D-41AA-A531-FEBC41C62D4F_1.pt, edge_index is correctly defined
# In file TCGA-R8-A6ML-01Z-00-DX5.771EFC95-EEB0-4029-B1D7-B0F5F94DCA35_1.pt, edge_index is correctly defined
# In file TCGA-TM-A84F-01Z-00-DX2.A2AB2F72-F232-4B60-97B1-1714C9261EAF_1.pt, edge_index is correctly defined
# In file TCGA-FG-A713-01Z-00-DX1.92B1CBC8-BF31-4748-92B6-EA4ACB3366FF_2.pt, edge_index is correctly defined
# In file TCGA-06-0882-01Z-00-DX2.7ad706e3-002e-4e29-88a9-18953ba422bf_1.pt, edge_index is correctly defined
# In file TCGA-DU-6407-01Z-00-DX1.191e7dfe-7bb3-446f-ba9d-8123b83f75d9_1.pt, edge_index is correctly defined
# In file TCGA-08-0246-01Z-00-DX1.F6215D43-42E5-41B6-AD72-FBC7E2A19D79_1.pt, edge_index is correctly defined
# In file TCGA-HT-7684-01Z-00-DX3.9B492026-0A0D-4CCD-8676-5E521A8D6A2B_1.pt, edge_index is correctly defined
# In file TCGA-S9-A7IS-01Z-00-DX1.193F4631-20AE-4001-93B0-4020821F524C_1.pt, edge_index is correctly defined
# In file TCGA-RR-A6KA-01Z-00-DX1.245ECFED-99ED-4A67-83FB-D194BFA2320C_1.pt, edge_index is correctly defined
# In file TCGA-DU-6400-01Z-00-DX1.46dd4fdb-66b4-445e-b9b7-c0eb8c114ed7_1.pt, edge_index is correctly defined
# In file TCGA-02-0289-01Z-00-DX1.1d9920df-d98f-4655-be62-14efec6d35bb_1.pt, edge_index is correctly defined
# In file TCGA-DB-A4XD-01Z-00-DX1.9CEDBD64-B9D3-4F8C-B51F-4E00085742A1_1.pt, edge_index is correctly defined
# In file TCGA-19-5951-01Z-00-DX1.a0b16abe-6c89-4fc1-95c5-56757360896b_1.pt, edge_index is correctly defined
# In file TCGA-14-0817-01Z-00-DX3.636820c0-c393-4590-bbe6-b56fe29e6b28_2.pt, edge_index is correctly defined
# In file TCGA-HT-7471-01Z-00-DX4.F749B9B2-71CD-4D27-814E-F117BEDCA3B9_1.pt, edge_index is correctly defined
# In file TCGA-HT-7880-01Z-00-DX2.3C084238-8203-4203-8F92-9CEE02922CCF_1.pt, edge_index is correctly defined
# In file TCGA-12-1092-01Z-00-DX1.78AA4D76-674D-4DCC-B46A-284FAC277653_1.pt, edge_index is correctly defined
# In file TCGA-S9-A6U8-01Z-00-DX1.5C7C8D4D-32E5-46B8-8223-E3FF487290DC_1.pt, edge_index is correctly defined
# In file TCGA-VM-A8C9-01Z-00-DX7.95A9AD6B-1293-485E-8A82-7A1939C7B9D4_1.pt, edge_index is correctly defined
# In file TCGA-HT-7603-01Z-00-DX2.B0E9C599-9BFB-45F1-8989-326A89CC05D0_2.pt, edge_index is correctly defined
# In file TCGA-06-0749-01Z-00-DX4.d44dbb9e-345f-46b0-a023-a1258d384b6f_2.pt, edge_index is correctly defined
# In file TCGA-DU-7306-01Z-00-DX1.254D61E6-1AE1-43DE-AABB-9FDDAC1355D4_1.pt, edge_index is correctly defined
# In file TCGA-27-1837-01Z-00-DX1.27b8fc01-d46e-459e-b4b9-6b80bf7dc6a9_2.pt, edge_index is correctly defined
# In file TCGA-HT-7681-01Z-00-DX4.E3A1EB6E-5F17-4D87-B4A6-4E5C4F049BD7_1.pt, edge_index is correctly defined
# In file TCGA-HT-A4DV-01Z-00-DX1.6F6DFF05-2F43-4E45-8C55-1A81DB16B421_1.pt, edge_index is correctly defined
# In file TCGA-VM-A8CH-01Z-00-DX2.DC834C4C-ADA5-436C-80DD-303E45917C35_1.pt, edge_index is correctly defined
# In file TCGA-HW-7493-01Z-00-DX1.5cb8de89-ec52-43fc-b977-7135e2b09397_2.pt, edge_index is correctly defined
# In file TCGA-02-0048-01Z-00-DX1.ADB8ABD8-E1A1-4708-8ADF-0DE96AFADA27_1.pt, edge_index is correctly defined
# In file TCGA-19-5954-01Z-00-DX1.b2e11be4-3f71-4d05-9405-c41dee3fc5b5_1.pt, edge_index is correctly defined
# In file TCGA-RY-A843-01Z-00-DX1.CB0CAD7E-B970-419A-902D-2F97660D2372_1.pt, edge_index is correctly defined
# In file TCGA-06-0214-01Z-00-DX3.a2d6733a-d151-434f-bd63-ed3977dfd3af_3.pt, edge_index is correctly defined
# In file TCGA-HT-7686-01Z-00-DX3.7B4FA34C-A4FB-49EC-B150-943FE2778642_1.pt, edge_index is correctly defined
# In file TCGA-S9-A7R1-01Z-00-DX1.9FAB9E82-AC0C-4902-BB8B-3620DCC21832_1.pt, edge_index is correctly defined
# In file TCGA-VM-A8CA-01Z-00-DX3.DF5FF5C7-CCF8-41BD-9FF5-3D1185E350B8_1.pt, edge_index is correctly defined
# In file TCGA-27-2519-01Z-00-DX1.C630FE42-2691-4735-83EB-6F78AAA407B3_1.pt, edge_index is correctly defined
# In file TCGA-06-0122-01Z-00-DX3.f14607a9-7121-42ed-9889-40d4261a6d07_1.pt, edge_index is correctly defined
# In file TCGA-HT-7602-01Z-00-DX2.7DA69565-ACB1-4EB5-BE8E-D653B4BDDAB7_1.pt, edge_index is correctly defined
# In file TCGA-06-0876-01Z-00-DX1.4268ceff-f46b-4d72-8606-45e79d935325_2.pt, edge_index is correctly defined
# In file TCGA-02-0075-01Z-00-DX1.2BFAAE68-2B16-4F00-B412-074E7073EBD3_1.pt, edge_index is correctly defined
# In file TCGA-FG-7637-01Z-00-DX1.29BC8289-EC8E-4182-A235-C7AC5DAC9A0E_1.pt, edge_index is correctly defined
# In file TCGA-HT-7858-01Z-00-DX4.7F6E369E-6CA5-4C61-A0B6-75C3EDDED6A9_1.pt, edge_index is correctly defined
# In file TCGA-DU-8161-01Z-00-DX1.f8fa74fe-4793-47dc-9dc1-10e636835536_1.pt, edge_index is correctly defined
# In file TCGA-02-0010-01Z-00-DX2.5334831b-8e1f-4b61-bbf6-0f6e950a1b2f_1.pt, edge_index is correctly defined
# In file TCGA-DU-7014-01Z-00-DX1.8BF185BC-AE93-4FA6-8672-10CFA214FF62_1.pt, edge_index is correctly defined
# In file TCGA-81-5911-01Z-00-DX1.343731a3-b399-461e-aa3e-7b22e583a061_1.pt, edge_index is correctly defined
# In file TCGA-VM-A8CA-01Z-00-DX2.7A15A9CB-AD1E-49B5-81C9-8FFFFEDBDE44_1.pt, edge_index is correctly defined
# In file TCGA-HW-7489-01Z-00-DX1.4586f9f6-ff9b-4966-a487-769d135024dd_1.pt, edge_index is correctly defined
# In file TCGA-HT-7856-01Z-00-DX3.A795080A-8724-45FA-BB57-7F155CECC55B_1.pt, edge_index is correctly defined
# In file TCGA-HT-7620-01Z-00-DX2.B41E3E8E-CC4C-4EFE-B7AB-4DC51AD5C558_1.pt, edge_index is correctly defined
# In file TCGA-HT-7856-01Z-00-DX7.6C56F340-6578-4F0C-8E65-099D99760143_2.pt, edge_index is correctly defined
# In file TCGA-CS-6666-01Z-00-DX1.6F91FE79-CCA6-401C-9C3C-74B2F9C9DF4A_2.pt, edge_index is correctly defined
# In file TCGA-FG-6691-01Z-00-DX1.d5e614cf-985b-4ca1-9ded-4ff57e938df1_1.pt, edge_index is correctly defined
# In file TCGA-81-5910-01Z-00-DX1.c823aaad-81c4-4fa6-8aa9-3b447eed912c_1.pt, edge_index is correctly defined
# In file TCGA-R8-A6MK-01Z-00-DX6.695AD627-C157-4804-AE53-5E0E6AAD07CC_1.pt, edge_index is correctly defined
# In file TCGA-27-1836-01Z-00-DX4.e54cb874-8c4b-4f64-89b1-af6891cc6d83_2.pt, edge_index is correctly defined
# In file TCGA-HW-A5KM-01Z-00-DX1.A8D3FF2B-3E88-46E0-8EFE-E2820F352EB1_1.pt, edge_index is correctly defined
# In file TCGA-02-0025-01Z-00-DX1.bea1009d-61ab-48dc-a6ae-530761306d4c_2.pt, edge_index is correctly defined
# In file TCGA-DH-A7UR-01Z-00-DX1.CD0C3921-255F-4415-BE61-240068DD1C9D_1.pt, edge_index is correctly defined
# In file TCGA-QH-A6CW-01Z-00-DX1.08892E79-CE6E-41BA-9070-740335844F2C_1.pt, edge_index is correctly defined
# In file TCGA-DH-A669-01Z-00-DX1.C4952318-5DA2-44E0-96AE-EE85C761C45D_2.pt, edge_index is correctly defined
# In file TCGA-HT-7480-01Z-00-DX2.F7CD8FA9-0DD2-47E5-9A40-957AA6DE5770_1.pt, edge_index is correctly defined
# In file TCGA-TM-A84B-01Z-00-DX1.8736E13D-D47F-462E-BD06-61767245C2F5_1.pt, edge_index is correctly defined
# In file TCGA-TQ-A8XE-02Z-00-DX1.818964A4-457E-4658-AF46-C89629B24EF4_1.pt, edge_index is correctly defined
# In file TCGA-14-1795-01Z-00-DX1.ef38b022-4f63-4ec2-a26b-3900d6bc73fc_2.pt, edge_index is correctly defined
# In file TCGA-87-5896-01Z-00-DX1.07E786CA-2345-4437-A0EF-6D26FDF9F387_2.pt, edge_index is correctly defined
# In file TCGA-06-5414-01Z-00-DX1.9b71e393-8801-480b-90a0-ee533ed24b0c_1.pt, edge_index is correctly defined
# In file TCGA-HT-7877-01Z-00-DX4.024CAAF1-188E-4F2E-AAA7-E354B89478D9_1.pt, edge_index is correctly defined
# In file TCGA-DU-8163-01Z-00-DX1.0f6383ea-6dd4-4424-b7b1-ec19d17d8d1a_1.pt, edge_index is correctly defined
# In file TCGA-06-0213-01Z-00-DX5.09126b9a-a487-4a3e-ad6c-935a2786ce47_2.pt, edge_index is correctly defined
# In file TCGA-HT-7601-01Z-00-DX2.CF1F7F86-5B2B-4A72-9128-56079A376CB2_1.pt, edge_index is correctly defined
# In file TCGA-06-0169-01Z-00-DX1.a471a09b-1488-4d1e-9945-6c487bfb081f_2.pt, edge_index is correctly defined
# In file TCGA-QH-A6X4-01Z-00-DX1.59C962C6-B2F6-4156-BA5F-ADAEF54BA4D8_1.pt, edge_index is correctly defined
# In file TCGA-12-3649-01Z-00-DX3.23C7DD3E-4B58-42A7-A0AD-B7F2B004C733_2.pt, edge_index is correctly defined
# In file TCGA-12-0826-01Z-00-DX2.EBD12563-948E-4983-8F96-FE56B8358EE2_2.pt, edge_index is correctly defined
# In file TCGA-12-0821-01Z-00-DX1.EDD83394-E7FE-4D05-9BBB-8D971DE305F4_2.pt, edge_index is correctly defined
# In file TCGA-HT-7604-01Z-00-DX1.6889187F-B89A-4CC0-8224-709DFF523FEE_2.pt, edge_index is correctly defined
# In file TCGA-27-1834-01Z-00-DX1.6a999465-48e8-4dff-8ef2-1c31bd33ce27_1.pt, edge_index is correctly defined
# In file TCGA-26-1799-01Z-00-DX1.630B7217-0B01-4CDD-8ABF-0EC4CF293476_2.pt, edge_index is correctly defined
# In file TCGA-S9-A6TY-01Z-00-DX1.C4A9E841-C3F4-4752-93E8-6478B7B88E60_3.pt, edge_index is correctly defined
# In file TCGA-06-0743-01Z-00-DX1.efc295e1-bb7b-4706-99e9-01901c3869d2_2.pt, edge_index is correctly defined
# In file TCGA-02-0281-01Z-00-DX1.6db34ca2-a4f6-4efb-adfa-05bd51f9fda2_2.pt, edge_index is correctly defined
# In file TCGA-06-0126-01Z-00-DX2.9754eddf-27d1-44ae-8bf7-74fa7c6ae431_2.pt, edge_index is correctly defined
# In file TCGA-HT-8114-01Z-00-DX1.C91CF38E-8921-4CCB-97E7-E285E3F7E6AC_1.pt, edge_index is correctly defined
# In file TCGA-R8-A6MK-01Z-00-DX1.CD613162-8078-4FB2-99A4-ED8E524FE2C3_1.pt, edge_index is correctly defined
# In file TCGA-02-0258-01Z-00-DX2.83DFCB56-FA4A-4F9D-ADA3-CE0C15C81A92_2.pt, edge_index is correctly defined
# In file TCGA-HT-7482-01Z-00-DX5.07FE2627-7614-4877-858A-1665A8CA20C9_2.pt, edge_index is correctly defined
# In file TCGA-TQ-A7RF-01Z-00-DX1.0243E73B-9B79-46C0-BA92-E8BA46E56036_1.pt, edge_index is correctly defined
# In file TCGA-DB-A75P-01Z-00-DX1.11655479-5A76-4689-B8F6-319F882B5EB7_1.pt, edge_index is correctly defined
# In file TCGA-HT-7609-01Z-00-DX1.8989643C-6505-468E-BEE4-8F105D4CE4A0_1.pt, edge_index is correctly defined
# In file TCGA-HT-7606-01Z-00-DX1.A30069C4-4819-421F-8A67-FE7457440229_1.pt, edge_index is correctly defined
# In file TCGA-14-1821-01Z-00-DX1.eef79762-89fb-47f5-9f43-1e6a906e5745_1.pt, edge_index is correctly defined
# In file TCGA-08-0349-01Z-00-DX1.3D53FE9F-E4E6-4D73-A339-CCF9CDD81288_2.pt, edge_index is correctly defined
# In file TCGA-02-0070-01Z-00-DX1.5E0E6185-E40B-4BDB-A762-03399FBD7C12_1.pt, edge_index is correctly defined
# In file TCGA-06-0168-01Z-00-DX3.6a390bd7-bbe8-4cdf-a562-2ef52d781186_2.pt, edge_index is correctly defined
# In file TCGA-19-1386-01Z-00-DX1.07c678e9-131c-4548-a70f-bcff22967210_1.pt, edge_index is correctly defined
# In file TCGA-HT-7689-01Z-00-DX3.8AE3ABC7-70E8-4804-94B2-C274ACBCA2CC_2.pt, edge_index is correctly defined
# In file TCGA-IK-7675-01Z-00-DX1.1afabdc4-ee6b-4a8a-8f9f-2bdead91ee76_2.pt, edge_index is correctly defined
# In file TCGA-S9-A6U6-01Z-00-DX1.23CAAC2B-577F-4262-85C1-6000F6EDFDEA_1.pt, edge_index is correctly defined
# In file TCGA-DB-A64S-01Z-00-DX1.E44CE325-25A2-4669-8843-E7462547C004_1.pt, edge_index is correctly defined
# In file TCGA-DU-8164-01Z-00-DX1.7a39faea-a8f4-4da9-a3e9-b899192445c8_2.pt, edge_index is correctly defined
# In file TCGA-06-0646-01Z-00-DX3.4e029189-ecef-4e12-be1a-c67fbdf8e22b_2.pt, edge_index is correctly defined
# In file TCGA-FG-8181-01Z-00-DX1.2902c472-2ec1-4e6c-a31e-e04b693ae4fb_1.pt, edge_index is correctly defined
# In file TCGA-DB-A4XE-01Z-00-DX2.895DAAFB-F994-4D4A-BCD7-30533BF94DC7_1.pt, edge_index is correctly defined
# In file TCGA-06-5416-01Z-00-DX1.43924d9a-373d-4c69-bc85-4d0d0f26fc14_2.pt, edge_index is correctly defined
# In file TCGA-06-0127-01Z-00-DX3.2e311110-3d6f-4864-9cd4-d8e716cb4db6_1.pt, edge_index is correctly defined
# In file TCGA-06-0176-01Z-00-DX4.98c6f166-0c65-47c5-9d26-c4e524b25577_1.pt, edge_index is correctly defined
# In file TCGA-HT-7676-01Z-00-DX1.620807AD-D67D-4705-A0AF-0FDCBD0B1C83_1.pt, edge_index is correctly defined
# In file TCGA-QH-A870-01Z-00-DX1.7A7F3987-7F2D-40BC-B1CA-09B0D095829F_1.pt, edge_index is correctly defined
# In file TCGA-QH-A6X3-01Z-00-DX1.FFC6757C-ED6A-4840-801F-CAB521558AE1_1.pt, edge_index is correctly defined
# In file TCGA-DH-A7UU-01Z-00-DX1.ECE10796-B224-404A-96BC-2D40601A7196_1.pt, edge_index is correctly defined
# In file TCGA-41-2575-01Z-00-DX1.cdce8f65-3ac2-4e03-a655-9176ea272f7e_1.pt, edge_index is correctly defined
# In file TCGA-06-0221-01Z-00-DX5.af8d73e4-58f1-4fb7-80dd-3d1e3a769874_1.pt, edge_index is correctly defined
# In file TCGA-HT-7482-01Z-00-DX9.694E652E-F952-414C-8295-5810C64454E3_1.pt, edge_index is correctly defined
# In file TCGA-HT-7858-01Z-00-DX2.81FBFB02-3710-49F6-8287-7D66043056AD_1.pt, edge_index is correctly defined
# In file TCGA-TM-A7CA-01Z-00-DX1.1CEBE1E1-7CBE-4F80-BAFC-828F7FA787B7_2.pt, edge_index is correctly defined
# In file TCGA-15-0742-01Z-00-DX2.2D163E93-6406-4F2C-8C90-8FBC4C1DD05F_1.pt, edge_index is correctly defined
# In file TCGA-12-0829-01Z-00-DX2.16FEE63B-65F2-4B6A-821D-488522B7826E_2.pt, edge_index is correctly defined
# In file TCGA-12-1093-01Z-00-DX2.620A2F8E-637C-4813-8088-C1EB231A0E64_2.pt, edge_index is correctly defined
# In file TCGA-QH-A6X5-01Z-00-DX1.A5F05E37-81B8-4390-8C0B-4DD1FDBC3853_1.pt, edge_index is correctly defined
# In file TCGA-02-0033-01Z-00-DX1.3c22d6a0-8b25-4f00-a499-b610d0f3c9a0_2.pt, edge_index is correctly defined
# In file TCGA-HT-7470-01Z-00-DX5.61392B7D-7FEA-401B-A16E-84DFBA7A3C6F_1.pt, edge_index is correctly defined
# In file TCGA-HT-7694-01Z-00-DX6.6CA051B4-B862-4630-86BE-6E6CF5575C78_1.pt, edge_index is correctly defined
# In file TCGA-HT-A5RA-01Z-00-DX1.F5DA3E78-30A6-41C5-9B50-410E795EF591_1.pt, edge_index is correctly defined
# In file TCGA-06-0133-01Z-00-DX1.47944c2e-fe0e-4d29-a7a5-2efc01d8dd94_2.pt, edge_index is correctly defined
# In file TCGA-HT-7677-01Z-00-DX5.A36DB19E-18E7-46B1-96F7-5AE56BEA8258_2.pt, edge_index is correctly defined
# In file TCGA-TQ-A7RW-01Z-00-DX1.05F422AA-ED7B-4D53-9B32-2B7CEFB85021_1.pt, edge_index is correctly defined
# In file TCGA-06-0749-01Z-00-DX4.d44dbb9e-345f-46b0-a023-a1258d384b6f_3.pt, edge_index is correctly defined
# In file TCGA-HT-7860-01Z-00-DX3.B6E8472B-CCDA-479A-B262-257AA0D52EB0_1.pt, edge_index is correctly defined
# In file TCGA-HT-7601-01Z-00-DX3.7CD5CD4C-F937-4931-A811-4DF8DDCD9C47_1.pt, edge_index is correctly defined
# In file TCGA-08-0524-01Z-00-DX3.313a243e-9d7a-4359-ad59-34f7cd6700db_2.pt, edge_index is correctly defined
# In file TCGA-06-0645-01Z-00-DX1.ffca480d-519c-4628-844c-946b5d000d01_2.pt, edge_index is correctly defined
# In file TCGA-02-0025-01Z-00-DX2.aa8923a0-2930-47f4-bbff-ceb080fafc9e_1.pt, edge_index is correctly defined
# In file TCGA-S9-A6WH-01Z-00-DX1.DDBE3C83-36D7-4969-BFFE-7FAA8014633B_1.pt, edge_index is correctly defined
# In file TCGA-06-0214-01Z-00-DX3.a2d6733a-d151-434f-bd63-ed3977dfd3af_2.pt, edge_index is correctly defined
# In file TCGA-02-0321-01Z-00-DX1.3c57c27d-4a4f-45af-bf8b-2bde421a42fa_1.pt, edge_index is correctly defined
# In file TCGA-27-1830-01Z-00-DX3.def849be-436e-4c2f-b269-10c3701b731b_1.pt, edge_index is correctly defined
# In file TCGA-FG-6690-01Z-00-DX1.69e8e3dd-91a5-442c-b0c9-8da45828b2c5_1.pt, edge_index is correctly defined
# In file TCGA-DU-7302-01Z-00-DX1.DF58DDC5-A6B1-4DE2-A048-A800099F8876_2.pt, edge_index is correctly defined
# In file TCGA-R8-A6MK-01Z-00-DXC.F741DE76-6E81-4DCF-A99F-659C1E398FB0_1.pt, edge_index is correctly defined
# In file TCGA-S9-A6U9-01Z-00-DX1.320C7173-3FAF-4661-8C0D-2C7B46BF17D9_1.pt, edge_index is correctly defined
# In file TCGA-DH-5142-01Z-00-DX1.3C7EAF01-4DC5-4FBE-849D-17DD3A6B5D8D_1.pt, edge_index is correctly defined
# In file TCGA-06-0878-01Z-00-DX1.75aa3e89-edcb-48c5-b778-7aae2085779f_1.pt, edge_index is correctly defined
# In file TCGA-TM-A84J-01Z-00-DX2.09328846-237C-4129-B214-311617D4AD93_1.pt, edge_index is correctly defined
# In file TCGA-TM-A7C3-01Z-00-DX1.8599EB66-7116-4CFA-A08D-9929AB55EA31_1.pt, edge_index is correctly defined
# In file TCGA-06-0178-01Z-00-DX2.e49e7c16-8370-42ae-977b-f4bd62ad49b6_1.pt, edge_index is correctly defined
# In file TCGA-HT-A616-01Z-00-DX1.5B0373D5-0979-4C1B-B9CA-08DFDCC9057B_1.pt, edge_index is correctly defined
# In file TCGA-DU-5847-01Z-00-DX1.b7d7de58-38b6-4686-8588-a2542c8595b4_1.pt, edge_index is correctly defined
# In file TCGA-HT-7857-01Z-00-DX2.B2E4366E-05CF-497E-AFA0-77E388C47E82_2.pt, edge_index is correctly defined
# In file TCGA-06-0156-01Z-00-DX1.1303eb2c-6cf6-4173-804c-d52a111263b5_1.pt, edge_index is correctly defined
# In file TCGA-DU-6408-01Z-00-DX1.341db4f1-3ab8-486e-91e8-0e60081e56f9_1.pt, edge_index is correctly defined
# In file TCGA-QH-A65Z-01Z-00-DX1.33A27DCF-3B96-468B-AF2C-6F394EFA44EF_2.pt, edge_index is correctly defined
# In file TCGA-15-1449-01Z-00-DX1.40E1E7B7-68DC-4841-86D6-E8DFA9B6959D_1.pt, edge_index is correctly defined
# In file TCGA-19-5947-01Z-00-DX1.8f5a42c0-87d5-4c73-9dcb-f054c5a7a96f_1.pt, edge_index is correctly defined
# In file TCGA-HT-7684-01Z-00-DX2.05D7C8C8-2DDB-4722-A4F9-466FDBCD66AA_2.pt, edge_index is correctly defined
# In file TCGA-4W-AA9T-01Z-00-DX1.A59F28A0-EE7F-44DE-931F-36E59C9F1A45_1.pt, edge_index is correctly defined
# In file TCGA-02-0037-01Z-00-DX1.4b9fe7a7-82a6-4188-b6a7-d74649506e27_2.pt, edge_index is correctly defined
# In file TCGA-S9-A6WO-01Z-00-DX1.7B2357DB-9EF4-4122-9A7E-F6F509A0A67C_1.pt, edge_index is correctly defined
# In file TCGA-02-0025-01Z-00-DX1.bea1009d-61ab-48dc-a6ae-530761306d4c_3.pt, edge_index is correctly defined
# In file TCGA-12-3650-01Z-00-DX1.3FC24EDA-D166-4868-99BA-B4A71924E409_2.pt, edge_index is correctly defined
# In file TCGA-DB-A75K-01Z-00-DX2.3F9418C2-334D-470A-928E-4D1E80A13978_1.pt, edge_index is correctly defined
# In file TCGA-14-1458-01Z-00-DX2.1839e27f-381d-463e-b30e-c38f0b2835c6_2.pt, edge_index is correctly defined
# In file TCGA-06-0879-01Z-00-DX1.644fc888-2c42-49dc-a461-072edd097f79_1.pt, edge_index is correctly defined
# In file TCGA-08-0385-01Z-00-DX1.04C20116-FB88-429D-B6A2-77CF029676F5_2.pt, edge_index is correctly defined
# In file TCGA-02-0007-01Z-00-DX1.a888f75e-6c41-44c3-8eb6-721f992873b8_1.pt, edge_index is correctly defined
# In file TCGA-HW-A5KK-01Z-00-DX1.DBE8A4F7-456E-4094-93D8-10D3238E86DD_1.pt, edge_index is correctly defined
# In file TCGA-HT-7677-01Z-00-DX1.F77F6FA2-116E-417A-9BB8-279FF089A69E_1.pt, edge_index is correctly defined
# In file TCGA-06-0129-01Z-00-DX3.bae772ea-dd36-47ec-8185-761989be3cc8_1.pt, edge_index is correctly defined
# In file TCGA-06-0237-01Z-00-DX2.684d94ed-c551-4460-96de-5cdfa0c36622_2.pt, edge_index is correctly defined
# In file TCGA-DU-7012-01Z-00-DX1.3D0ACB4F-8CBB-47F9-B015-0AFF70928A62_1.pt, edge_index is correctly defined
# In file TCGA-FG-5964-01Z-00-DX1.971827c7-4e41-4b8c-af02-01b340cf4cbd_1.pt, edge_index is correctly defined
# In file TCGA-HT-7695-01Z-00-DX1.30F75635-FD99-4F2C-9E03-2A7F9A78F6EC_2.pt, edge_index is correctly defined
# In file TCGA-06-0124-01Z-00-DX4.d91f6ca6-dc38-46cc-9803-ec754acd65c4_2.pt, edge_index is correctly defined
# In file TCGA-02-0026-01Z-00-DX1.d8f3085f-e418-47da-86bc-20db44ac6efd_1.pt, edge_index is correctly defined
# In file TCGA-HT-7605-01Z-00-DX4.05B0D4D8-29B6-4547-B3C0-22B547BDC061_1.pt, edge_index is correctly defined
# In file TCGA-06-0158-01Z-00-DX1.05358ff8-3c26-440a-9d51-bafa92cf4685_1.pt, edge_index is correctly defined
# In file TCGA-02-0337-01Z-00-DX1.c7d3d96c-789b-4844-8731-1279d44955ec_1.pt, edge_index is correctly defined
# In file TCGA-DB-5278-01Z-00-DX2.39A970EE-DD46-4766-82BE-6B9DBFE57F3E_1.pt, edge_index is correctly defined
# In file TCGA-41-5651-01Z-00-DX1.84aa5ff7-d54c-43d7-8f03-c9012d303926_2.pt, edge_index is correctly defined
# In file TCGA-HT-7694-01Z-00-DX5.D7561F24-C805-4E32-84C1-BE3FD1767AEC_2.pt, edge_index is correctly defined
# In file TCGA-S9-A6TY-01Z-00-DX1.C4A9E841-C3F4-4752-93E8-6478B7B88E60_2.pt, edge_index is correctly defined
# In file TCGA-DU-7011-01Z-00-DX1.839D54AF-A0C7-4DE4-A7D0-D19C760FFB3D_1.pt, edge_index is correctly defined
# In file TCGA-HT-8018-01Z-00-DX1.1C1BBFD4-8C4A-4A6F-8D64-70A4F41814AF_1.pt, edge_index is correctly defined
# In file TCGA-RR-A6KB-01Z-00-DX1.90E22C0F-CA68-4EEB-BB13-2DD67C895A94_1.pt, edge_index is correctly defined
# In file TCGA-08-0354-01Z-00-DX1.577F7E82-1CDD-4639-9079-AC24FCE94BF7_2.pt, edge_index is correctly defined
# In file TCGA-VM-A8CD-01Z-00-DX4.504C4EEF-6491-4A03-9A81-03259714F5BB_1.pt, edge_index is correctly defined
# In file TCGA-12-0615-01Z-00-DX3.57f0d9cc-9570-4c75-9c7b-d6e346b9e6bf_1.pt, edge_index is correctly defined
# In file TCGA-DB-A4X9-01Z-00-DX2.1C5A66A2-48A5-41B3-98C7-6B668438C4C1_1.pt, edge_index is correctly defined
# In file TCGA-12-0827-01Z-00-DX3.CC3B9B34-4BD8-4C93-ACC8-29BC2D3D93E0_2.pt, edge_index is correctly defined
# In file TCGA-08-0356-01Z-00-DX1.8E74B4EF-3D96-43F6-BAD5-4A33C9B21B6E_1.pt, edge_index is correctly defined
# In file TCGA-19-5960-01Z-00-DX1.3376dcf2-9873-445e-83a9-95c5b208efc7_1.pt, edge_index is correctly defined
# In file TCGA-08-0392-01Z-00-DX1.BB310D33-3C69-4C1B-BF5C-F0E7E025CF74_2.pt, edge_index is correctly defined
# In file TCGA-HT-7690-01Z-00-DX1.C810C130-7583-4700-B6B4-EE48175A1BE4_1.pt, edge_index is correctly defined
# In file TCGA-28-1751-01Z-00-DX1.9be1807e-2cd5-469d-a4ab-6730aa26fc95_1.pt, edge_index is correctly defined
# In file TCGA-VV-A829-01Z-00-DX1.C5464B6B-E673-4AFE-A5A1-7923F2C40450_1.pt, edge_index is correctly defined
# In file TCGA-CS-5395-01Z-00-DX1.791A154B-43D0-43BB-821C-929F13319FB6_1.pt, edge_index is correctly defined
# In file TCGA-HT-7855-01Z-00-DX1.D1CFAF92-BC0B-443C-8A5A-48147BD0FB84_1.pt, edge_index is correctly defined
# In file TCGA-CS-4943-01Z-00-DX1.F0F9BB61-4122-4C7B-B2E3-CF291EA88338_1.pt, edge_index is correctly defined
# In file TCGA-06-0646-01Z-00-DX3.4e029189-ecef-4e12-be1a-c67fbdf8e22b_3.pt, edge_index is correctly defined
# In file TCGA-HT-7877-01Z-00-DX1.F9F0B3D4-6802-49DC-8540-DF329FE1379D_1.pt, edge_index is correctly defined
# In file TCGA-06-0745-01Z-00-DX1.3e0f266b-f1b5-42cb-8633-8cea6ee0ba6e_1.pt, edge_index is correctly defined
# In file TCGA-19-5950-01Z-00-DX1.4ee3aa4f-8cd7-4acd-b6e3-2829adf8da7a_1.pt, edge_index is correctly defined
# In file TCGA-12-1095-01Z-00-DX3.7948F970-B60F-493C-9E18-65F7F5F7FCBE_2.pt, edge_index is correctly defined
# In file TCGA-R8-A6MK-01Z-00-DX3.23626B7D-35BE-46B4-8983-96AC9777166E_2.pt, edge_index is correctly defined
# In file TCGA-VM-A8CH-01Z-00-DX5.992B2EBF-4B11-441E-97DE-9167BDBF797D_1.pt, edge_index is correctly defined
# In file TCGA-14-1454-01Z-00-DX1.b61db33c-e8d4-4740-b565-5e62bc13e606_2.pt, edge_index is correctly defined
# In file TCGA-DU-6395-01Z-00-DX1.c2fa922a-48b9-46fe-87d3-ea18e925dd98_1.pt, edge_index is correctly defined
# In file TCGA-12-0707-01Z-00-DX1.96127c4a-82dd-4c27-9697-4d3b66bb29cb_1.pt, edge_index is correctly defined
# In file TCGA-DB-A4XE-01Z-00-DX1.C45CDC01-DCE7-404B-88E0-9EAF67E7A26E_1.pt, edge_index is correctly defined
# In file TCGA-FG-A4MT-02Z-00-DX5.BC137126-2035-4629-BCCF-EDDD39CC7178_1.pt, edge_index is correctly defined
# In file TCGA-02-0009-01Z-00-DX3.BAA1276B-E4D7-43D4-BDDF-807532462518_1.pt, edge_index is correctly defined
# In file TCGA-41-2573-01Z-00-DX1.aaa4085e-c7e0-4c03-8033-780f407b0d11_1.pt, edge_index is correctly defined
# In file TCGA-26-5136-01Z-00-DX1.ECD48B1B-C2BF-4DFE-8ED4-87353E00ED84_1.pt, edge_index is correctly defined
# In file TCGA-28-1750-01Z-00-DX1.b1455f64-6b43-4f2f-8434-d7fb53aadc51_2.pt, edge_index is correctly defined
# In file TCGA-12-0619-01Z-00-DX2.e305c038-1dd0-422f-87dd-8edaeace224d_1.pt, edge_index is correctly defined
# In file TCGA-HT-7620-01Z-00-DX1.109AADE8-D0F0-4D60-86C6-2B7C9377C0AE_1.pt, edge_index is correctly defined
# In file TCGA-TQ-A7RU-01Z-00-DX1.29C7A86C-6C94-480E-B74C-44ACC2B89A76_1.pt, edge_index is correctly defined
# In file TCGA-DU-7008-01Z-00-DX1.C4A4B091-9F79-4B12-AACE-521CF12DFF1C_1.pt, edge_index is correctly defined
# In file TCGA-S9-A7QW-01Z-00-DX1.C07FEA9E-6FED-46C9-9133-11A18A877832_1.pt, edge_index is correctly defined
# In file TCGA-HT-A61A-01Z-00-DX1.1E02526B-2D50-482D-B4A8-F326E9CE3F55_2.pt, edge_index is correctly defined
# In file TCGA-02-0446-01Z-00-DX2.DDC76DDC-183C-4B49-8F30-E7945BFDB0BD_1.pt, edge_index is correctly defined
# In file TCGA-06-0124-01Z-00-DX5.5fee1242-c113-4404-b504-23b607a3459f_1.pt, edge_index is correctly defined
# In file TCGA-HT-7470-01Z-00-DX4.204D0CF2-A22E-4428-8E8C-572432B86280_1.pt, edge_index is correctly defined
# In file TCGA-15-1447-01Z-00-DX3.41691182-D1C6-4899-9BC9-137361AB96AF_2.pt, edge_index is correctly defined
# In file TCGA-08-0244-01Z-00-DX1.37361959-E91D-4B2F-8AB5-A4ED4AEC3A6E_2.pt, edge_index is correctly defined
# In file TCGA-DH-A7US-01Z-00-DX1.0CC50064-5604-449F-8A97-860436784030_3.pt, edge_index is correctly defined
# In file TCGA-HT-7881-01Z-00-DX4.D87464C7-F498-4AB1-AE6E-F6F71C76CCAA_1.pt, edge_index is correctly defined
# In file TCGA-06-0211-01Z-00-DX2.dea01d17-0a8c-4e58-a82a-9b2de99258af_1.pt, edge_index is correctly defined
# In file TCGA-R8-A6MO-01Z-00-DX2.2C4F1A78-A9C9-481F-B00B-45CD0951EB6E_1.pt, edge_index is correctly defined
# In file TCGA-14-1402-01Z-00-DX3.c3663e36-b946-47de-ab1e-902dd9b97c06_1.pt, edge_index is correctly defined
# In file TCGA-14-0867-01Z-00-DX3.fa65c92f-2b67-4932-a468-3aab1d0fc6d3_1.pt, edge_index is correctly defined
# In file TCGA-S9-A6WN-01Z-00-DX1.FEEA7335-8225-4DA8-9AE1-3DA1B6EFCAE5_1.pt, edge_index is correctly defined
# In file TCGA-DU-8167-01Z-00-DX1.9ec81b46-f1e9-4611-b018-74f398cb4e90_1.pt, edge_index is correctly defined
# In file TCGA-12-0773-01Z-00-DX4.c6133111-f85e-4209-86ae-a8d5dab839d2_2.pt, edge_index is correctly defined
# In file TCGA-TQ-A7RV-02Z-00-DX1.098F3ECC-BAC0-4626-8BFF-577972244ACB_1.pt, edge_index is correctly defined
# In file TCGA-06-0141-01Z-00-DX3.0b0aaacd-38b1-46f4-b8bf-bf38c35e6188_1.pt, edge_index is correctly defined
# In file TCGA-HT-7620-01Z-00-DX4.5114FD3F-C228-4204-ABDD-91D7742FA32C_1.pt, edge_index is correctly defined
# In file TCGA-DB-5280-01Z-00-DX1.377DED7C-CE43-4735-A6C1-2C2D0A769B18_1.pt, edge_index is correctly defined
# In file TCGA-12-0772-01Z-00-DX2.25ab3b61-79ce-4096-a0db-4aff20919b6d_2.pt, edge_index is correctly defined
# In file TCGA-HT-7611-01Z-00-DX1.AE487FF3-EF5A-4CE5-8618-20F234A59F1E_1.pt, edge_index is correctly defined
# In file TCGA-FG-7634-01Z-00-DX1.BF0F2F3E-2CAD-495C-A0E6-D8194BCC4A77_1.pt, edge_index is correctly defined
# In file TCGA-02-0015-01Z-00-DX1.73c07790-a054-4725-b123-4f09a2de961a_2.pt, edge_index is correctly defined
# In file TCGA-FG-8187-01Z-00-DX1.4af1e387-0e5f-43e2-a237-fad93a0209a7_1.pt, edge_index is correctly defined
# In file TCGA-26-1440-01Z-00-DX1.A60DA9D7-1F44-4802-82EB-9572D951B7EE_1.pt, edge_index is correctly defined
# In file TCGA-02-0052-01Z-00-DX1.93BA650B-4E71-43D8-9974-16185F906EB8_1.pt, edge_index is correctly defined
# In file TCGA-19-5953-01Z-00-DX1.c069ba1e-7819-4e22-b1cd-c431b93b1eb8_2.pt, edge_index is correctly defined
# In file TCGA-19-5955-01Z-00-DX1.ef448923-881d-47cd-89fd-261f0a1c7f49_1.pt, edge_index is correctly defined
# In file TCGA-R8-A6MK-01Z-00-DXD.26CA7DE4-FEBC-4544-829F-163A7FB04DA7_1.pt, edge_index is correctly defined
# In file TCGA-08-0352-01Z-00-DX2.d1d43af6-fc93-4d1d-a432-8c5e9ee9b04f_1.pt, edge_index is correctly defined
# In file TCGA-HT-8013-01Z-00-DX1.2C2597D7-8F5C-406B-97C1-0EFD907B4FA5_1.pt, edge_index is correctly defined
# In file TCGA-02-0332-01Z-00-DX1.4d7017ac-1ad9-4359-b641-273c1cb2cc14_1.pt, edge_index is correctly defined
# In file TCGA-08-0516-01Z-00-DX1.B384463F-9206-424F-B829-600FB602722C_2.pt, edge_index is correctly defined
# In file TCGA-S9-A6U5-01Z-00-DX1.BC695617-5AF4-4D43-91D9-1BC5A9DBB8DA_2.pt, edge_index is correctly defined
# In file TCGA-02-0010-01Z-00-DX4.07de2e55-a8fe-40ee-9e98-bcb78050b9f7_1.pt, edge_index is correctly defined
# In file TCGA-02-0266-01Z-00-DX1.fe847b40-3972-4189-9ba8-cd37a4eda01d_2.pt, edge_index is correctly defined
# In file TCGA-06-0188-01Z-00-DX5.133f13cc-4387-4abc-b47d-05b5870cfe2e_1.pt, edge_index is correctly defined
# In file TCGA-FG-A4MX-01Z-00-DX1.64CE3174-2194-461A-AD83-D0CF49FD27EF_1.pt, edge_index is correctly defined
# In file TCGA-DB-A64R-01Z-00-DX1.0A2B114A-F7CA-4D94-A7E4-CA482F92B214_1.pt, edge_index is correctly defined
# In file TCGA-DU-6404-01Z-00-DX1.93c15688-f5b2-40bc-85eb-ff2661e16d4e_1.pt, edge_index is correctly defined
# In file TCGA-06-5413-01Z-00-DX1.6c5e8a47-c2d0-4873-9b32-36857c5f67ac_2.pt, edge_index is correctly defined
# In file TCGA-HT-7474-01Z-00-DX1.B3E88862-6C35-4E30-B374-A7BC80231B8C_2.pt, edge_index is correctly defined
# In file TCGA-06-0216-01Z-00-DX1.dfa5d225-9ccb-44af-83f2-9af3f2e825db_1.pt, edge_index is correctly defined
# In file TCGA-DH-A66D-01Z-00-DX1.95468350-314C-40AF-B409-14E3DE8B2AF8_1.pt, edge_index is correctly defined
# In file TCGA-06-0185-01Z-00-DX1.63a424a7-724c-45f4-9eee-c7fc1eda49a6_2.pt, edge_index is correctly defined
# In file TCGA-12-0819-01Z-00-DX2.CA37F7BE-86D9-421F-B5A5-87E2BDDF7AAB_1.pt, edge_index is correctly defined
# In file TCGA-HT-7469-01Z-00-DX1.53A588BD-3B74-4DB6-BE8D-A6E80119E3EB_1.pt, edge_index is correctly defined
# In file TCGA-HW-A5KL-01Z-00-DX1.9BE3C44C-8738-4F55-8CCD-DBE3A92A88CE_1.pt, edge_index is correctly defined
# In file TCGA-HT-7693-01Z-00-DX2.7BF80AA3-52C6-4AA2-B85E-93BF3F906EA9_1.pt, edge_index is correctly defined
# In file TCGA-DB-5277-01Z-00-DX1.635F8997-B57B-402D-8889-BE84CA858B16_1.pt, edge_index is correctly defined
# In file TCGA-06-0208-01Z-00-DX2.7578ffcb-f02a-41dd-8456-71f333407a6d_2.pt, edge_index is correctly defined
# In file TCGA-HT-7854-01Z-00-DX2.FDFCD4CA-A809-4DDF-A680-FB4A6948F575_1.pt, edge_index is correctly defined
# In file TCGA-HT-7606-01Z-00-DX2.6A6AB593-4A06-4670-97CD-48EF2BEB5403_1.pt, edge_index is correctly defined
# In file TCGA-06-5412-01Z-00-DX1.039632bd-2493-4a78-839c-3734eae662f8_1.pt, edge_index is correctly defined
# In file TCGA-HT-7877-01Z-00-DX3.F6A0A6D3-46ED-44F3-9982-149CB29AD402_1.pt, edge_index is correctly defined
# In file TCGA-FG-A6J3-01Z-00-DX1.AA7E89A2-D29C-4C47-9905-4016302CC92C_1.pt, edge_index is correctly defined
# In file TCGA-02-0024-01Z-00-DX1.d4cec60d-e2b6-41d1-92af-2d24f15b03a9_1.pt, edge_index is correctly defined
# In file TCGA-HT-7473-01Z-00-DX5.4626DB85-EEB8-4EEE-9912-4EA2200BCA0A_1.pt, edge_index is correctly defined
# In file TCGA-VM-A8CF-01Z-00-DX3.3CED09BD-4062-4573-A075-84461B82F5B4_1.pt, edge_index is correctly defined
# In file TCGA-CS-6665-01Z-00-DX1.0805163E-0752-4383-B9EC-877B505672B8_2.pt, edge_index is correctly defined
# In file TCGA-08-0389-01Z-00-DX1.F833FAB6-9A7B-4BBB-BF0B-3D4F18DBB8A2_1.pt, edge_index is correctly defined
# In file TCGA-06-6388-01Z-00-DX1.14c09c5f-3ea4-4e1e-a5e6-308325383165_2.pt, edge_index is correctly defined
# In file TCGA-06-5411-01Z-00-DX1.08bf7f79-7346-4b1b-b8a7-e24abf11e848_1.pt, edge_index is correctly defined
# In file TCGA-02-0317-01Z-00-DX1.e9d98c2a-d388-4c03-9e00-c23e7c2a6faf_1.pt, edge_index is correctly defined
# In file TCGA-HT-7602-01Z-00-DX1.6CF85DA2-1BCC-47ED-BFB6-1149510273A6_1.pt, edge_index is correctly defined
# In file TCGA-27-2528-01Z-00-DX1.8160EE21-D3C3-4FFF-8BB6-979235C1F963_2.pt, edge_index is correctly defined
# In file TCGA-26-5132-01Z-00-DX1.390D6188-C9C6-4DD2-8CCE-A43444F28EE5_1.pt, edge_index is correctly defined
# In file TCGA-06-1084-01Z-00-DX2.f36f31e3-2d41-410c-a5b4-91f1f7508eec_1.pt, edge_index is correctly defined
# In file TCGA-R8-A6MO-01Z-00-DX1.C29AAA07-B083-47E5-9F55-D3A06F3A5415_1.pt, edge_index is correctly defined
# In file TCGA-02-0115-01Z-00-DX1.9261988C-1002-4E99-8611-46C722FE49C5_1.pt, edge_index is correctly defined
# In file TCGA-TM-A84S-01Z-00-DX1.5ED4FD31-AE61-4E45-B202-420B37C847D9_1.pt, edge_index is correctly defined
# In file TCGA-HT-7480-01Z-00-DX1.42E0C267-020A-464E-9652-2068BEC181B8_1.pt, edge_index is correctly defined
# In file TCGA-FG-A4MT-02Z-00-DX6.0CD6853F-A85E-4AD5-86BD-0925F6542453_1.pt, edge_index is correctly defined
# In file TCGA-DU-7309-01Z-00-DX1.C4D67475-FE07-4B6A-A766-A4D339A51561_2.pt, edge_index is correctly defined
# In file TCGA-06-0137-01Z-00-DX4.140591f4-dc4d-493d-9a70-bed1335dd1c1_1.pt, edge_index is correctly defined
# In file TCGA-HT-7608-01Z-00-DX1.75E16CEE-44C7-43C1-91BB-AB9EC4385419_1.pt, edge_index is correctly defined
# In file TCGA-HT-7480-01Z-00-DX4.C69D99AA-7FAD-4741-8A68-FCF694D07180_1.pt, edge_index is correctly defined
# In file TCGA-HT-7856-01Z-00-DX8.AC662672-AF5D-4034-A36C-FD93CA70ACDA_1.pt, edge_index is correctly defined
# In file TCGA-CS-6670-01Z-00-DX1.A767AC46-DA02-41C6-8829-AE53DB0F386E_2.pt, edge_index is correctly defined
# In file TCGA-02-0054-01Z-00-DX1.B8AFCEF2-4ED1-4329-854A-313AAECF3093_1.pt, edge_index is correctly defined
# In file TCGA-S9-A6WQ-01Z-00-DX1.F3EDD859-8FEF-48B4-BFEA-36BCCE34F030_1.pt, edge_index is correctly defined
# In file TCGA-15-1446-01Z-00-DX1.2BBD436C-A472-4B8F-8C15-F5692B05E30B_2.pt, edge_index is correctly defined
# In file TCGA-06-0152-01Z-00-DX5.d43177f3-75c0-4049-8af7-76c2c12e6411_1.pt, edge_index is correctly defined
# In file TCGA-06-0148-01Z-00-DX1.3b19c82d-c52d-4514-8bf6-5b0f629c18de_2.pt, edge_index is correctly defined
# In file TCGA-28-1752-01Z-00-DX1.e24f30ab-133e-4a77-9df7-c136beea14a2_1.pt, edge_index is correctly defined
# In file TCGA-EZ-7264-01Z-00-DX1.80a61d74-77d9-4998-bb55-213767a588ff_2.pt, edge_index is correctly defined
# In file TCGA-19-5959-01Z-00-DX1.86907dc7-c0ce-48e6-b67c-a3134f8b4aa2_1.pt, edge_index is correctly defined
# In file TCGA-02-0099-01Z-00-DX1.E3BD2989-346F-4580-9E67-23BEEA35094E_1.pt, edge_index is correctly defined
# In file TCGA-06-0209-01Z-00-DX2.696bfc96-020e-41c4-9a3a-e34e170d0e50_1.pt, edge_index is correctly defined
# In file TCGA-DU-8168-01Z-00-DX1.e89da367-c6d4-4eb6-8d2e-96a0f8c8cd4a_1.pt, edge_index is correctly defined
# In file TCGA-12-1097-01Z-00-DX3.164386D1-9C06-43AF-8E69-338893CC7291_1.pt, edge_index is correctly defined
# In file TCGA-TM-A7C5-01Z-00-DX1.6B493BB3-6497-47AE-8D35-CC7C35868E6E_1.pt, edge_index is correctly defined
# In file TCGA-HT-7877-01Z-00-DX2.FFF695A6-CC46-49AC-8E93-78076B660630_1.pt, edge_index is correctly defined
# In file TCGA-FG-A4MU-01Z-00-DX1.F557204B-3E0E-4961-ACCA-0567C66E318F_3.pt, edge_index is correctly defined
# In file TCGA-28-1757-01Z-00-DX1.ef0fd824-d5cb-484e-8296-4064cf183f75_1.pt, edge_index is correctly defined
# In file TCGA-HW-8319-01Z-00-DX1.DB3012DE-00C2-4425-B3E4-6F5FF19CE290_1.pt, edge_index is correctly defined
# In file TCGA-DB-A75M-01Z-00-DX1.418C4BE6-EDC6-47D1-B3E0-B6B082426D8F_2.pt, edge_index is correctly defined
# In file TCGA-12-0656-01Z-00-DX1.08311e56-c469-459d-8dcc-22dc26be4372_1.pt, edge_index is correctly defined
# In file TCGA-FG-A4MT-02Z-00-DX1.F0250524-BEDE-4C23-A3E9-F1D927F5E561_2.pt, edge_index is correctly defined
# In file TCGA-02-0317-01Z-00-DX2.15FFEA24-40C1-42C8-AE60-9CD346EE171A_1.pt, edge_index is correctly defined
# In file TCGA-08-0353-01Z-00-DX1.C29C6177-3C62-4399-A030-C936156E79D2_1.pt, edge_index is correctly defined
# In file TCGA-VM-A8C9-01Z-00-DX9.DEF6A890-B06E-42BC-A653-A6BF5E324B8D_1.pt, edge_index is correctly defined
# In file TCGA-14-0783-01Z-00-DX1.904587e4-393d-4e4d-9337-ff2655f87ca8_2.pt, edge_index is correctly defined
# In file TCGA-12-0780-01Z-00-DX3.6ecd72ef-2b14-4751-b8f7-f105049742dd_2.pt, edge_index is correctly defined
# In file TCGA-DB-A75L-01Z-00-DX1.132A6368-8624-4091-BCDA-261155BBD426_1.pt, edge_index is correctly defined
# In file TCGA-06-0195-01Z-00-DX5.f0adc4a5-671d-4b0f-9ae1-de3869c199b3_3.pt, edge_index is correctly defined
# In file TCGA-HT-7688-01Z-00-DX3.26184958-7A53-40E5-B2C4-773266C369EA_2.pt, edge_index is correctly defined
# In file TCGA-12-0776-01Z-00-DX3.d5213d31-2793-4d3b-911d-81535193ee42_1.pt, edge_index is correctly defined
# In file TCGA-06-0644-01Z-00-DX1.bbce7e5c-6df3-4963-ac75-9f566a2fde12_1.pt, edge_index is correctly defined
# In file TCGA-14-1829-01Z-00-DX1.0cdf6765-4947-4635-9b87-987b70a66562_2.pt, edge_index is correctly defined
# In file TCGA-HT-7602-01Z-00-DX3.7C695E52-525C-4BC8-8CA9-B79A8C17DC70_1.pt, edge_index is correctly defined
# In file TCGA-HT-7687-01Z-00-DX4.C225C0CD-3031-4916-9DE6-5A00B0B03913_1.pt, edge_index is correctly defined
# In file TCGA-12-3646-01Z-00-DX1.31628F37-ED94-452B-9667-B6AA8158CA47_2.pt, edge_index is correctly defined
# In file TCGA-S9-A6TU-01Z-00-DX1.58000391-215E-4740-AD40-1489B348922B_1.pt, edge_index is correctly defined
# In file TCGA-HT-7609-01Z-00-DX4.01359B55-A14D-4986-99C7-CA16262354A1_1.pt, edge_index is correctly defined
# In file TCGA-R8-A6MO-01Z-00-DXD.D62DDC11-431F-41A4-9F9F-DA33E90D9DC4_1.pt, edge_index is correctly defined
# In file TCGA-06-0187-01Z-00-DX4.defa1a76-b328-474e-8bdb-2382cc05ada4_1.pt, edge_index is correctly defined
# In file TCGA-TM-A84R-01Z-00-DX1.26D7F00E-85DD-49E9-BCA3-AAA25ECD2E5F_1.pt, edge_index is correctly defined
# In file TCGA-41-3392-01Z-00-DX1.2d3dba82-f1cb-4589-bad1-f27ca388049b_1.pt, edge_index is correctly defined
# In file TCGA-12-1598-01Z-00-DX2.2A4CDADD-272F-4C1A-82D4-E8EE0DB742A9_1.pt, edge_index is correctly defined
# In file TCGA-VM-A8CA-01Z-00-DX7.4C172C51-63E5-44DE-978E-DE3BBA23B24E_1.pt, edge_index is correctly defined
# In file TCGA-08-0518-01Z-00-DX7.37016e3a-813a-4319-a8fa-7dea055ccc68_1.pt, edge_index is correctly defined
# In file TCGA-VM-A8CA-01Z-00-DX6.07221643-D7F3-4E38-9A63-C7B3B46E570B_1.pt, edge_index is correctly defined
# In file TCGA-26-1442-01Z-00-DX1.FD8D4EB7-AD5E-49E8-BD0B-6CDDEA8DDB35_1.pt, edge_index is correctly defined
# In file TCGA-HT-A617-01Z-00-DX1.5865A8D2-3251-4D1C-B093-334C65ACC7A5_2.pt, edge_index is correctly defined
# In file TCGA-02-0440-01Z-00-DX1.4fef88c9-eff7-4e00-be19-d0db2871329a_1.pt, edge_index is correctly defined
# In file TCGA-HT-7470-01Z-00-DX9.27D6011C-13F4-43EB-B114-20193EA59044_1.pt, edge_index is correctly defined
# In file TCGA-WY-A858-01Z-00-DX1.4D36E628-9C20-46D9-8617-C6903A1535A9_1.pt, edge_index is correctly defined
# In file TCGA-HT-7677-01Z-00-DX8.A45BF8C9-024C-4466-B63E-07D0B3F7F8AB_2.pt, edge_index is correctly defined
# In file TCGA-VV-A86M-01Z-00-DX1.3D542AC0-4000-40AA-A574-791B8772F956_1.pt, edge_index is correctly defined
# In file TCGA-08-0375-01Z-00-DX1.76B7554F-0C77-4E2B-A1F7-633E896FB5E3_2.pt, edge_index is correctly defined
# In file TCGA-HT-7603-01Z-00-DX1.FACE593F-FFD2-4A1B-B7ED-B05D50F06E44_1.pt, edge_index is correctly defined
# In file TCGA-HT-7902-01Z-00-DX1.B9265DE0-438A-4D0E-A828-EE5019422E0C_1.pt, edge_index is correctly defined
# In file TCGA-12-0769-01Z-00-DX1.ebd0fe2a-1113-413f-a04d-e5cf7c0335ff_1.pt, edge_index is correctly defined
# In file TCGA-06-0174-01Z-00-DX3.23b6e12e-dfc1-4c6f-903e-170038a0e055_1.pt, edge_index is correctly defined
# In file TCGA-DU-7010-01Z-00-DX1.542F36CC-9685-4780-94EB-B664CECFF09D_1.pt, edge_index is correctly defined
# In file TCGA-VM-A8CF-01Z-00-DX5.90CAA7E9-55BA-41D6-A5D1-280E761B17BC_1.pt, edge_index is correctly defined
# In file TCGA-08-0509-01Z-00-DX1.712969EE-F3D2-444C-9A81-179724D6DFDA_1.pt, edge_index is correctly defined
# In file TCGA-06-0122-01Z-00-DX1.fb97a66e-2720-45e9-af2a-694505d1b808_1.pt, edge_index is correctly defined
# In file TCGA-27-2521-01Z-00-DX1.31BCEBD8-3A69-4560-8077-40AF5BA0B955_1.pt, edge_index is correctly defined
# In file TCGA-08-0350-01Z-00-DX1.60549F68-E548-4634-8851-B24818FDFA40_1.pt, edge_index is correctly defined
# In file TCGA-DB-5276-01Z-00-DX1.3921BD4C-CC46-43A4-BECF-AAB9A35E6682_2.pt, edge_index is correctly defined
# ...
# In file TCGA-CS-5393-01Z-00-DX1.E67462B3-7899-4085-97A8-DF9A7B45E2E0_1.pt, edge_index is correctly defined
# In file TCGA-27-1838-01Z-00-DX1.3ada1ada-fb14-4761-84f9-66a339e86e73_1.pt, edge_index is correctly defined
# In file TCGA-S9-A6U0-01Z-00-DX1.43BCB230-1388-424F-A218-F0F222691102_1.pt, edge_index is correctly defined
# In file TCGA-HT-7856-01Z-00-DX5.39E17A43-12E3-444F-BAD4-BEFCDAB90491_1.pt, edge_index is correctly defined
# In file TCGA-DU-6397-01Z-00-DX1.82694102-b70e-4919-bd88-644692606d52_1.pt, edge_index is correctly defined
# In file TCGA-41-2572-01Z-00-DX1.a89d5edf-1466-40b8-929f-d8b5554f31b8_1.pt, edge_index is correctly defined
# In file TCGA-12-0618-01Z-00-DX1.e174afd8-0708-4e92-8c4b-9578062e56ea_1.pt, edge_index is correctly defined
# In file TCGA-FG-8191-01Z-00-DX1.cf5a8abc-ba6d-438f-b070-95fc79ba0fce_2.pt, edge_index is correctly defined
# In file TCGA-02-0009-01Z-00-DX2.f5c99ad0-30b1-4f1b-afb0-0a355068eacc_2.pt, edge_index is correctly defined
# In file TCGA-02-0451-01Z-00-DX2.02487460-bb28-4750-ac02-f0e92d843aa5_1.pt, edge_index is correctly defined
# In file TCGA-HT-7609-01Z-00-DX3.D3050BBE-3F54-4662-9867-608D69759599_1.pt, edge_index is correctly defined
# In file TCGA-14-1825-01Z-00-DX1.f09203b7-73b2-4600-a92e-b097508b86ba_1.pt, edge_index is correctly defined
# In file TCGA-HT-8110-01Z-00-DX1.C7649C75-0A7E-49B4-9550-6C3AE1145CCB_1.pt, edge_index is correctly defined
# In file TCGA-QH-A6X9-01Z-00-DX1.D8ECA1DD-68D3-4987-9B23-1F9FA81955E0_1.pt, edge_index is correctly defined
# In file TCGA-OX-A56R-01Z-00-DX1.6AC88CAE-73F3-4ECF-AE06-E347574EB6E8_1.pt, edge_index is correctly defined
# In file TCGA-08-0345-01Z-00-DX1.DEC032EE-E0D3-4F8A-9008-063BDC17DFBF_1.pt, edge_index is correctly defined
# In file TCGA-R8-A6ML-01Z-00-DX7.A75A40C8-7318-4715-A5EB-0AF659884685_1.pt, edge_index is correctly defined
# In file TCGA-19-A6J5-01Z-00-DX1.2667B32C-FDF4-4197-BD32-56D6124BD01C_1.pt, edge_index is correctly defined
# In file TCGA-FG-A4MT-02Z-00-DX4.5CC76ADE-AFCE-4BDC-AC27-4CD962926AD6_1.pt, edge_index is correctly defined
# In file TCGA-02-0034-01Z-00-DX2.f86120e8-3574-4a1d-a42b-248e86e2674f_2.pt, edge_index is correctly defined
# In file TCGA-TQ-A7RK-02Z-00-DX1.81EF0869-9C37-45B0-B548-10436269B3FB_1.pt, edge_index is correctly defined
# In file TCGA-12-0662-01Z-00-DX4.29f739c2-f70f-4ad5-ae7f-9f94c14adca2_1.pt, edge_index is correctly defined
# In file TCGA-06-5417-01Z-00-DX1.bf70952e-fdb5-4d0a-b0c1-2823e908f599_1.pt, edge_index is correctly defined
# In file TCGA-08-0521-01Z-00-DX1.ea283930-0c6b-45b4-8331-86e5982a0401_1.pt, edge_index is correctly defined
# In file TCGA-HT-7680-01Z-00-DX2.97354FFD-A8D4-400F-9FEA-7C69C47D4A57_1.pt, edge_index is correctly defined
# In file TCGA-HT-7469-01Z-00-DX1.53A588BD-3B74-4DB6-BE8D-A6E80119E3EB_3.pt, edge_index is correctly defined
# In file TCGA-HT-7608-01Z-00-DX5.5F3FC71C-11AD-4745-8867-657557D196E2_1.pt, edge_index is correctly defined
# In file TCGA-HW-7490-01Z-00-DX1.2109dc98-1288-4da2-963e-4544db680603_1.pt, edge_index is correctly defined
# In file TCGA-14-1451-01Z-00-DX1.e97169f1-5aa9-41f1-9780-349d5744bfae_1.pt, edge_index is correctly defined
# In file TCGA-06-0157-01Z-00-DX1.0bb9c6aa-3a9c-4d2b-9ce6-9a1cf54882a4_2.pt, edge_index is correctly defined
# In file TCGA-S9-A7J1-01Z-00-DX1.E6934DF9-A2DF-4454-B927-CD481786EB3A_1.pt, edge_index is correctly defined
# In file TCGA-06-0216-01Z-00-DX1.dfa5d225-9ccb-44af-83f2-9af3f2e825db_3.pt, edge_index is correctly defined
# In file TCGA-TM-A84F-01Z-00-DX1.F12CDFC4-91D7-422E-83BE-BB987DCCD3AD_1.pt, edge_index is correctly defined
# In file TCGA-08-0245-01Z-00-DX1.CFCAFA75-E128-47D9-9F16-43A175738145_1.pt, edge_index is correctly defined
# In file TCGA-02-0085-01Z-00-DX1.ac1b3db0-1647-4303-9a95-d67fab6bf700_1.pt, edge_index is correctly defined
# In file TCGA-02-0317-01Z-00-DX1.e9d98c2a-d388-4c03-9e00-c23e7c2a6faf_3.pt, edge_index is correctly defined
# In file TCGA-FG-A713-01Z-00-DX1.92B1CBC8-BF31-4748-92B6-EA4ACB3366FF_1.pt, edge_index is correctly defined
# In file TCGA-HT-7481-01Z-00-DX1.19124734-8096-44FA-ABF1-40BA8BE318DF_1.pt, edge_index is correctly defined
# In file TCGA-HT-7879-01Z-00-DX2.1F7DF69E-64B9-4B29-B4EE-FDE88E51E1F2_1.pt, edge_index is correctly defined
# In file TCGA-W9-A837-01Z-00-DX1.F0E23873-46D1-460F-AA53-930D7934E687_1.pt, edge_index is correctly defined
# In file TCGA-08-0357-01Z-00-DX1.F0E652B4-DE1D-41AA-A531-FEBC41C62D4F_2.pt, edge_index is correctly defined
# In file TCGA-TM-A7CF-02Z-00-DX1.7EFCCDDE-B065-4367-8C0B-91A3D4E277D5_2.pt, edge_index is correctly defined
# In file TCGA-HT-7616-01Z-00-DX1.480841A6-F62C-4E95-A4EA-8DC975894933_1.pt, edge_index is correctly defined
# In file TCGA-S9-A6WI-01Z-00-DX1.D3D90B50-C15D-4EB0-B721-AD655EA6F97A_1.pt, edge_index is correctly defined
# In file TCGA-08-0529-01Z-00-DX1.c0aefbea-1aa2-4091-b320-dbdab0964b6d_1.pt, edge_index is correctly defined
# In file TCGA-VM-A8CD-01Z-00-DX2.355165A0-D1C3-4345-B151-B94591102389_1.pt, edge_index is correctly defined
# In file TCGA-VM-A8CF-01Z-00-DX2.9BB80EF8-5600-4BA5-879D-46B8B6D0776D_1.pt, edge_index is correctly defined
# In file TCGA-02-0289-01Z-00-DX1.1d9920df-d98f-4655-be62-14efec6d35bb_2.pt, edge_index is correctly defined
# In file TCGA-DB-A4XD-01Z-00-DX1.9CEDBD64-B9D3-4F8C-B51F-4E00085742A1_2.pt, edge_index is correctly defined
# In file TCGA-19-5951-01Z-00-DX1.a0b16abe-6c89-4fc1-95c5-56757360896b_2.pt, edge_index is correctly defined
# In file TCGA-RY-A83X-01Z-00-DX1.1DA8284F-B532-478B-B7BC-C578BE36E2CA_1.pt, edge_index is correctly defined
# In file TCGA-HT-7879-01Z-00-DX1.4ACC4CED-056B-4F63-86E6-D08206991030_1.pt, edge_index is correctly defined
# In file TCGA-DU-6399-01Z-00-DX1.1a964643-a0f0-4338-8976-3bf5f832236c_1.pt, edge_index is correctly defined
# In file TCGA-06-0188-01Z-00-DX6.d85af94e-adbb-4489-b98f-57d2431e28f6_1.pt, edge_index is correctly defined
# In file TCGA-HW-7493-01Z-00-DX1.5cb8de89-ec52-43fc-b977-7135e2b09397_1.pt, edge_index is correctly defined
# In file TCGA-HT-7603-01Z-00-DX2.B0E9C599-9BFB-45F1-8989-326A89CC05D0_1.pt, edge_index is correctly defined
# In file TCGA-06-0749-01Z-00-DX4.d44dbb9e-345f-46b0-a023-a1258d384b6f_1.pt, edge_index is correctly defined
# In file TCGA-HT-7684-01Z-00-DX5.E8C6D6FE-D37E-4E31-9321-CB725674B0B4_1.pt, edge_index is correctly defined
# In file TCGA-27-1837-01Z-00-DX1.27b8fc01-d46e-459e-b4b9-6b80bf7dc6a9_1.pt, edge_index is correctly defined
# In file TCGA-KT-A74X-01Z-00-DX2.9CF10646-A8BA-44B7-B099-423861E84494_1.pt, edge_index is correctly defined
# In file TCGA-DB-A64O-01Z-00-DX1.E143BA84-8D09-4FA0-A58F-AF6BEE4E8451_1.pt, edge_index is correctly defined
# In file TCGA-02-0422-01Z-00-DX2.E354E17A-0E49-4BC7-A8B3-DB6CD1B936EE_1.pt, edge_index is correctly defined
# In file TCGA-14-0817-01Z-00-DX3.636820c0-c393-4590-bbe6-b56fe29e6b28_1.pt, edge_index is correctly defined
# In file TCGA-27-2519-01Z-00-DX1.C630FE42-2691-4735-83EB-6F78AAA407B3_2.pt, edge_index is correctly defined
# In file TCGA-HT-7602-01Z-00-DX2.7DA69565-ACB1-4EB5-BE8E-D653B4BDDAB7_2.pt, edge_index is correctly defined
# In file TCGA-06-0876-01Z-00-DX1.4268ceff-f46b-4d72-8606-45e79d935325_1.pt, edge_index is correctly defined
# In file TCGA-FG-7637-01Z-00-DX1.29BC8289-EC8E-4182-A235-C7AC5DAC9A0E_2.pt, edge_index is correctly defined
# In file TCGA-DB-5273-01Z-00-DX2.4240617C-BD85-4841-A61E-62EB9C143076_1.pt, edge_index is correctly defined
# In file TCGA-12-0670-01Z-00-DX2.9B4706D7-1C81-4FD9-8E82-0223149306B6_1.pt, edge_index is correctly defined
# In file TCGA-FG-8188-01Z-00-DX3.0238ac4e-c4ea-486e-9884-7853729294a9_1.pt, edge_index is correctly defined
# In file TCGA-DB-A4XA-01Z-00-DX2.78A6831F-EA66-4A88-BFEC-C731A00A9C36_1.pt, edge_index is correctly defined
# In file TCGA-S9-A7J0-01Z-00-DX1.F7AEDF07-33C2-4238-A04F-758C8EF58851_1.pt, edge_index is correctly defined
# In file TCGA-FG-6688-01Z-00-DX1.8f282d89-9838-4295-8c58-9ee29d915b07_1.pt, edge_index is correctly defined
# In file TCGA-S9-A6WH-01Z-00-DX1.DDBE3C83-36D7-4969-BFFE-7FAA8014633B_3.pt, edge_index is correctly defined
# In file TCGA-VM-A8CB-01Z-00-DX7.E1F6875A-18A8-4696-AC98-383E476ABE97_1.pt, edge_index is correctly defined
# In file TCGA-DB-A64L-01Z-00-DX1.95A7A10B-D31F-4A8E-B847-2F43F9DC1C46_1.pt, edge_index is correctly defined
# In file TCGA-HT-7620-01Z-00-DX2.B41E3E8E-CC4C-4EFE-B7AB-4DC51AD5C558_2.pt, edge_index is correctly defined
# In file TCGA-HT-7856-01Z-00-DX7.6C56F340-6578-4F0C-8E65-099D99760143_1.pt, edge_index is correctly defined
# In file TCGA-CS-6666-01Z-00-DX1.6F91FE79-CCA6-401C-9C3C-74B2F9C9DF4A_1.pt, edge_index is correctly defined
# In file TCGA-DB-5270-01Z-00-DX1.E0795F24-4D23-408A-8871-2675EC577C23_1.pt, edge_index is correctly defined
# In file TCGA-HW-7489-01Z-00-DX1.4586f9f6-ff9b-4966-a487-769d135024dd_2.pt, edge_index is correctly defined
# In file TCGA-VM-A8CH-01Z-00-DX6.284D2734-21E1-4C09-9578-6BFE42131D43_1.pt, edge_index is correctly defined
# In file TCGA-HW-8320-01Z-00-DX1.71FC4C29-1D2A-4227-82B9-9D59A9AF38A0_1.pt, edge_index is correctly defined
# In file TCGA-DH-5142-01Z-00-DX1.3C7EAF01-4DC5-4FBE-849D-17DD3A6B5D8D_3.pt, edge_index is correctly defined
# In file TCGA-06-0122-01Z-00-DX2.8ccb2e31-03b4-4b49-88af-8412b68a901c_1.pt, edge_index is correctly defined
# In file TCGA-02-0010-01Z-00-DX2.5334831b-8e1f-4b61-bbf6-0f6e950a1b2f_2.pt, edge_index is correctly defined
# In file TCGA-HT-7468-01Z-00-DX3.623EF604-9D08-4596-8917-E5609A1CFBE1_1.pt, edge_index is correctly defined
# In file TCGA-QH-A6CW-01Z-00-DX1.08892E79-CE6E-41BA-9070-740335844F2C_2.pt, edge_index is correctly defined
# In file TCGA-DH-A7UR-01Z-00-DX1.CD0C3921-255F-4415-BE61-240068DD1C9D_2.pt, edge_index is correctly defined
# In file TCGA-FG-A60K-01Z-00-DX2.43CB9666-FF7D-4000-8EF4-C56F1619E56E_1.pt, edge_index is correctly defined
# In file TCGA-HT-8558-01Z-00-DX1.0580D6EA-4DFC-456F-AD7E-EED64753A97B_1.pt, edge_index is correctly defined
# In file TCGA-02-0025-01Z-00-DX1.bea1009d-61ab-48dc-a6ae-530761306d4c_1.pt, edge_index is correctly defined
# In file TCGA-F6-A8O4-01Z-00-DX1.28B744E2-072B-469B-9DDE-4DB6ADC57777_1.pt, edge_index is correctly defined
# In file TCGA-HT-7688-01Z-00-DX9.16051FC4-9676-42F4-B5AD-6614D0286BC5_1.pt, edge_index is correctly defined
# In file TCGA-27-1836-01Z-00-DX4.e54cb874-8c4b-4f64-89b1-af6891cc6d83_1.pt, edge_index is correctly defined
# In file TCGA-28-1746-01Z-00-DX1.06f187d2-b5e8-4b37-bb23-a707d0059944_1.pt, edge_index is correctly defined
# In file TCGA-HW-A5KM-01Z-00-DX1.A8D3FF2B-3E88-46E0-8EFE-E2820F352EB1_2.pt, edge_index is correctly defined
# In file TCGA-81-5910-01Z-00-DX1.c823aaad-81c4-4fa6-8aa9-3b447eed912c_2.pt, edge_index is correctly defined
# In file TCGA-FG-5964-01Z-00-DX1.971827c7-4e41-4b8c-af02-01b340cf4cbd_3.pt, edge_index is correctly defined
# In file TCGA-06-0213-01Z-00-DX5.09126b9a-a487-4a3e-ad6c-935a2786ce47_1.pt, edge_index is correctly defined
# In file TCGA-CS-4941-01Z-00-DX1.86D516B5-C648-4249-8C6A-7F9A6A56CB4F_1.pt, edge_index is correctly defined
# In file TCGA-06-0169-01Z-00-DX1.a471a09b-1488-4d1e-9945-6c487bfb081f_1.pt, edge_index is correctly defined
# In file TCGA-HT-7601-01Z-00-DX2.CF1F7F86-5B2B-4A72-9128-56079A376CB2_2.pt, edge_index is correctly defined
# In file TCGA-HT-7482-01Z-00-DX1.A56F0B29-767B-48C6-A522-7A94F868889B_1.pt, edge_index is correctly defined
# In file TCGA-06-5414-01Z-00-DX1.9b71e393-8801-480b-90a0-ee533ed24b0c_2.pt, edge_index is correctly defined
# In file TCGA-VM-A8C9-01Z-00-DX4.20D5EE02-3CD2-45C4-AF74-539DC859369B_1.pt, edge_index is correctly defined
# In file TCGA-HT-7874-01Z-00-DX2.E36EF1D2-10E5-4AE4-AF5C-6DCA6AF636E6_1.pt, edge_index is correctly defined
# In file TCGA-FG-A6IZ-01Z-00-DX1.4E27D4BA-5E6C-4E51-97F4-5EE6148A4F29_1.pt, edge_index is correctly defined
# In file TCGA-VM-A8CB-01Z-00-DX3.4DAB7FB0-0C2E-43D8-9E4F-F5C1720AA78F_1.pt, edge_index is correctly defined
# In file TCGA-14-1795-01Z-00-DX1.ef38b022-4f63-4ec2-a26b-3900d6bc73fc_1.pt, edge_index is correctly defined
# In file TCGA-12-3644-01Z-00-DX1.2FCEC3DA-D09A-42BE-AAA1-35EC272B0895_1.pt, edge_index is correctly defined
# In file TCGA-06-0128-01Z-00-DX4.91ce4e5d-c790-4175-a1c7-be965ae1df40_1.pt, edge_index is correctly defined
# In file TCGA-87-5896-01Z-00-DX1.07E786CA-2345-4437-A0EF-6D26FDF9F387_1.pt, edge_index is correctly defined
# In file TCGA-DH-A669-01Z-00-DX1.C4952318-5DA2-44E0-96AE-EE85C761C45D_1.pt, edge_index is correctly defined
# In file TCGA-DB-5274-01Z-00-DX1.28F042EC-7A2E-4AEC-B67A-EF1684BC1361_1.pt, edge_index is correctly defined
# In file TCGA-TM-A84B-01Z-00-DX1.8736E13D-D47F-462E-BD06-61767245C2F5_2.pt, edge_index is correctly defined
# In file TCGA-02-0281-01Z-00-DX1.6db34ca2-a4f6-4efb-adfa-05bd51f9fda2_1.pt, edge_index is correctly defined
# In file TCGA-06-0126-01Z-00-DX2.9754eddf-27d1-44ae-8bf7-74fa7c6ae431_1.pt, edge_index is correctly defined
# In file TCGA-WY-A85A-01Z-00-DX1.CB302B89-F89A-40FD-A7DE-6E12BEFBA2AE_1.pt, edge_index is correctly defined
# In file TCGA-WY-A859-01Z-00-DX1.650758FF-1BE8-4A56-8A9A-319BA0363D8F_1.pt, edge_index is correctly defined
# In file TCGA-HT-7604-01Z-00-DX1.6889187F-B89A-4CC0-8224-709DFF523FEE_1.pt, edge_index is correctly defined
# In file TCGA-27-1834-01Z-00-DX1.6a999465-48e8-4dff-8ef2-1c31bd33ce27_2.pt, edge_index is correctly defined
# In file TCGA-26-1799-01Z-00-DX1.630B7217-0B01-4CDD-8ABF-0EC4CF293476_1.pt, edge_index is correctly defined
# In file TCGA-06-0743-01Z-00-DX1.efc295e1-bb7b-4706-99e9-01901c3869d2_1.pt, edge_index is correctly defined
# In file TCGA-HT-7605-01Z-00-DX2.B8FE3450-CB38-49E2-9486-F20388AA1246_1.pt, edge_index is correctly defined
# In file TCGA-12-3649-01Z-00-DX3.23C7DD3E-4B58-42A7-A0AD-B7F2B004C733_1.pt, edge_index is correctly defined
# In file TCGA-12-0826-01Z-00-DX2.EBD12563-948E-4983-8F96-FE56B8358EE2_1.pt, edge_index is correctly defined
# In file TCGA-VM-A8C9-01Z-00-DX3.E0BF1E61-5F3C-4E15-8A6A-3E1A351FC0A7_1.pt, edge_index is correctly defined
# In file TCGA-12-0821-01Z-00-DX1.EDD83394-E7FE-4D05-9BBB-8D971DE305F4_1.pt, edge_index is correctly defined
# In file TCGA-DU-6542-01Z-00-DX1.ccdb126c-5e8b-4094-9282-c2ea5d0d6a04_1.pt, edge_index is correctly defined
# In file TCGA-HT-7480-01Z-00-DX5.AB789ABF-9E84-4F24-935F-80EA240CBACF_1.pt, edge_index is correctly defined
# In file TCGA-R8-A6MK-01Z-00-DXA.088A6643-8205-45A9-AF02-8C039D9F653E_1.pt, edge_index is correctly defined
# In file TCGA-QH-A6X4-01Z-00-DX1.59C962C6-B2F6-4156-BA5F-ADAEF54BA4D8_2.pt, edge_index is correctly defined
# In file TCGA-TM-A7CF-01Z-00-DX1.EB905EDB-5AC5-41C4-AB00-526DD3820524_1.pt, edge_index is correctly defined
# In file TCGA-DU-8164-01Z-00-DX1.7a39faea-a8f4-4da9-a3e9-b899192445c8_1.pt, edge_index is correctly defined
# In file TCGA-06-0646-01Z-00-DX3.4e029189-ecef-4e12-be1a-c67fbdf8e22b_1.pt, edge_index is correctly defined
# In file TCGA-DB-A4XE-01Z-00-DX2.895DAAFB-F994-4D4A-BCD7-30533BF94DC7_2.pt, edge_index is correctly defined
# In file TCGA-HT-7482-01Z-00-DX3.8C1621A1-2C68-49CC-A859-C1F2EA450865_1.pt, edge_index is correctly defined
# In file TCGA-06-0168-01Z-00-DX3.6a390bd7-bbe8-4cdf-a562-2ef52d781186_1.pt, edge_index is correctly defined
# In file TCGA-DU-7007-01Z-00-DX1.DB64D884-B8AA-4540-BF6F-BF83B1D15A26_1.pt, edge_index is correctly defined
# In file TCGA-HT-7689-01Z-00-DX3.8AE3ABC7-70E8-4804-94B2-C274ACBCA2CC_1.pt, edge_index is correctly defined
# In file TCGA-IK-7675-01Z-00-DX1.1afabdc4-ee6b-4a8a-8f9f-2bdead91ee76_1.pt, edge_index is correctly defined
# In file TCGA-14-1821-01Z-00-DX1.eef79762-89fb-47f5-9f43-1e6a906e5745_2.pt, edge_index is correctly defined
# In file TCGA-08-0349-01Z-00-DX1.3D53FE9F-E4E6-4D73-A339-CCF9CDD81288_1.pt, edge_index is correctly defined
# In file TCGA-HT-7686-01Z-00-DX2.17E34786-0450-4752-878B-D12DE2D8877D_1.pt, edge_index is correctly defined
# In file TCGA-TM-A84L-01Z-00-DX1.411C2D0B-921E-4B0A-95ED-DF9A89AFC76B_1.pt, edge_index is correctly defined
# In file TCGA-02-0258-01Z-00-DX2.83DFCB56-FA4A-4F9D-ADA3-CE0C15C81A92_1.pt, edge_index is correctly defined
# In file TCGA-HT-7482-01Z-00-DX5.07FE2627-7614-4877-858A-1665A8CA20C9_1.pt, edge_index is correctly defined
# In file TCGA-HT-7610-01Z-00-DX1.2817EDDA-8B51-4796-B830-DE12FD7998F0_1.pt, edge_index is correctly defined
# Correct edge_index count: 1505

# %% [markdown]
# ## The .pt files in `all_st_patches_512_cpc` folder, which comes from nine times duplication from `all_st_cpc`

# %%
import os
import torch
from torch_geometric.data import Data

directory = "data/TCGA_GBMLGG/all_st_patches_512_cpc"

correct_edge_index_count = 0

# iterate through each file in the directory
for filename in os.listdir(directory):
    if filename.endswith(".pt"):
        filepath = os.path.join(directory, filename)

        data = torch.load(filepath)

        num_nodes = data.num_nodes
        max_edge_index = data.edge_index.max().item()

        if max_edge_index >= num_nodes:
            print(
                f"In file {filename}, edge_index max ({max_edge_index}) is greater than or equal to the number of nodes ({num_nodes})."
            )
        else:
            correct_edge_index_count += 1

print(f"Correct edge_index count: {correct_edge_index_count}")
# Out:
# Correct edge_index count: 13545

# %% [markdown]
# ## The .pt files in the orifinal `all_st_cpc_img` folder

# %%
import os
import torch
import torch_geometric
from torch_geometric.data import Data

# the pt_bi files from the original all_st_cpc_img folder
directory = "/Users/shizhexu/Downloads/TCGA_GBMLGG/all_st_cpc_img/pt_bi"

correct_edge_index_count = 0
incorrect_edge_index_count = 0

for filename in os.listdir(directory):
    if filename.endswith(".pt"):
        filepath = os.path.join(directory, filename)

        old_data = torch.load(filepath)

        new_data = torch_geometric.data.data.Data.from_dict(old_data.__dict__)

        # check if edge_index.max() is greater than the number of nodes
        num_nodes = new_data.num_nodes
        max_edge_index = new_data.edge_index.max().item()

        if max_edge_index >= num_nodes:
            print(
                f"In file {filename}, edge_index max ({max_edge_index}) is greater than or equal to the number of nodes ({num_nodes})."
            )
            incorrect_edge_index_count += 1
        else:
            correct_edge_index_count += 1

print(f"Correct edge_index count: {correct_edge_index_count}")
print(f"Incorrect edge_index count: {incorrect_edge_index_count}")
# Out:
# In file TCGA-HW-7493-01Z-00-DX1.5cb8de89-ec52-43fc-b977-7135e2b09397_2.pt, edge_index max (209) is greater than or equal to the number of nodes (205).
# In file TCGA-06-0876-01Z-00-DX1.4268ceff-f46b-4d72-8606-45e79d935325_2.pt, edge_index max (760) is greater than or equal to the number of nodes (752).
# In file TCGA-19-1386-01Z-00-DX1.07c678e9-131c-4548-a70f-bcff22967210_1.pt, edge_index max (804) is greater than or equal to the number of nodes (798).
# In file TCGA-06-0176-01Z-00-DX4.98c6f166-0c65-47c5-9d26-c4e524b25577_1.pt, edge_index max (691) is greater than or equal to the number of nodes (687).
# In file TCGA-QH-A6X5-01Z-00-DX1.A5F05E37-81B8-4390-8C0B-4DD1FDBC3853_1.pt, edge_index max (500) is greater than or equal to the number of nodes (494).
# In file TCGA-06-0156-01Z-00-DX1.1303eb2c-6cf6-4173-804c-d52a111263b5_1.pt, edge_index max (333) is greater than or equal to the number of nodes (329).
# In file TCGA-HT-7690-01Z-00-DX1.C810C130-7583-4700-B6B4-EE48175A1BE4_1.pt, edge_index max (874) is greater than or equal to the number of nodes (862).
# In file TCGA-HT-7877-01Z-00-DX2.FFF695A6-CC46-49AC-8E93-78076B660630_1.pt, edge_index max (509) is greater than or equal to the number of nodes (501).
# In file TCGA-HT-A74L-01Z-00-DX1.E51CD31D-B564-4E49-8630-3485CE49B9B6_1.pt, edge_index max (596) is greater than or equal to the number of nodes (592).
# In file TCGA-HT-7608-01Z-00-DX3.67EA3645-3674-453C-9AD7-46A2EA060905_1.pt, edge_index max (313) is greater than or equal to the number of nodes (305).
# In file TCGA-02-0079-01Z-00-DX1.846D3C54-C7BD-477F-A33A-D7641DD1CCEC_2.pt, edge_index max (364) is greater than or equal to the number of nodes (358).
# In file TCGA-DU-7015-01Z-00-DX1.E604489D-E82C-4129-9CDC-16AD1D33B3F2_1.pt, edge_index max (471) is greater than or equal to the number of nodes (456).
# In file TCGA-VM-A8CA-01Z-00-DX5.424C74A2-33EE-4C5B-9D9B-630CC5D59A9F_1.pt, edge_index max (401) is greater than or equal to the number of nodes (396).
# In file TCGA-12-3648-01Z-00-DX1.BB8213F9-1553-45D3-9F5C-DE8519B0F0CD_1.pt, edge_index max (740) is greater than or equal to the number of nodes (710).
# In file TCGA-02-0326-01Z-00-DX2.BDF167EF-A9C3-4BCC-AF1E-F68C55149FF9_2.pt, edge_index max (455) is greater than or equal to the number of nodes (444).
# In file TCGA-08-0509-01Z-00-DX1.712969EE-F3D2-444C-9A81-179724D6DFDA_2.pt, edge_index max (416) is greater than or equal to the number of nodes (410).
# In file TCGA-HT-7607-01Z-00-DX2.8989537E-4871-42A4-94B8-260A341E2C9C_2.pt, edge_index max (380) is greater than or equal to the number of nodes (373).
# In file TCGA-HT-8015-01Z-00-DX1.A88F5665-931F-4C94-B856-5EE0E6020E84_1.pt, edge_index max (562) is greater than or equal to the number of nodes (557).
# In file TCGA-FG-A713-01Z-00-DX4.12FA5CBD-8304-414F-99BD-2FDA6F9DAC00_1.pt, edge_index max (304) is greater than or equal to the number of nodes (295).
# In file TCGA-02-0085-01Z-00-DX1.ac1b3db0-1647-4303-9a95-d67fab6bf700_1.pt, edge_index max (569) is greater than or equal to the number of nodes (560).
# In file TCGA-DH-A7UR-01Z-00-DX1.CD0C3921-255F-4415-BE61-240068DD1C9D_2.pt, edge_index max (568) is greater than or equal to the number of nodes (563).
# Correct edge_index count: 1484
# Incorrect edge_index count: 21

# %% [markdown]
# ## The example .pt files in `cell_graph_reconstruction` examples

# %%
import os
import torch
import torch_geometric
from torch_geometric.data import Data

# the pt_bi files from the original all_st_cpc_img folder
directory = "cell_graph_reconstruction/example_data/pts"

correct_edge_index_count = 0
incorrect_edge_index_count = 0

for filename in os.listdir(directory):
    if filename.endswith(".pt"):
        filepath = os.path.join(directory, filename)

        old_data = torch.load(filepath)

        new_data = torch_geometric.data.data.Data.from_dict(old_data.__dict__)

        # check if edge_index.max() is greater than the number of nodes
        num_nodes = new_data.num_nodes
        max_edge_index = new_data.edge_index.max().item()

        if max_edge_index >= num_nodes:
            print(
                f"In file {filename}, edge_index max ({max_edge_index}) is greater than or equal to the number of nodes ({num_nodes})."
            )
            incorrect_edge_index_count += 1
        else:
            correct_edge_index_count += 1

print(f"Correct edge_index count: {correct_edge_index_count}")
print(f"Incorrect edge_index count: {incorrect_edge_index_count}")
# Out:
# Correct edge_index count: 3
# Incorrect edge_index count: 0

# %% [markdown]
# ## how to preprocess the invalid edge indices

# %%
import torch
import torch_geometric

old_data = torch.load(
    "/Users/shizhexu/Downloads/TCGA_GBMLGG/all_st_cpc_img/pt_bi/TCGA-HW-7493-01Z-00-DX1.5cb8de89-ec52-43fc-b977-7135e2b09397_2.pt"
)
new_data = torch_geometric.data.data.Data.from_dict(old_data.__dict__)

print(new_data)
print(new_data.edge_index.max())
print(new_data.edge_index)

num_nodes = new_data.num_nodes
edge_index = new_data.edge_index

valid_edges_mask = (edge_index[0] < num_nodes) & (edge_index[1] < num_nodes)

filtered_edge_index = edge_index[:, valid_edges_mask]

new_data.edge_index = filtered_edge_index

print(new_data)
print(new_data.edge_index.max())
print(new_data.edge_index)

# processed_file_path = os.path.join(directory, 'processed_data.pt')
# torch.save(data, processed_file_path)
# Out:
# Data(x=[205, 1036], edge_index=[2, 1014], edge_attr=[1014, 1], centroid=[205, 2])
# tensor(209)
# tensor([[  0,   0,   0,  ..., 209, 209, 209],
#         [  6,  13,  15,  ..., 195, 202, 204]])
# Data(x=[205, 1036], edge_index=[2, 976], edge_attr=[1014, 1], centroid=[205, 2])
# tensor(204)
# tensor([[  0,   0,   0,  ..., 204, 204, 204],
#         [  6,  13,  15,  ..., 187, 189, 202]])

# %%
import os
import torch
import torch_geometric
from torch_geometric.data import Data

# the pt_bi files from the original all_st_cpc_img folder
directory = "data/TCGA_GBMLGG/all_st_cpc_img/pt_bi"

correct_edge_index_count = 0

for filename in os.listdir(directory):
    if filename.endswith(".pt"):
        filepath = os.path.join(directory, filename)

        old_data = torch.load(filepath)

        new_data = torch_geometric.data.data.Data.from_dict(old_data.__dict__)

        # check if edge_index.max() is greater than the number of nodes
        num_nodes = new_data.num_nodes
        max_edge_index = new_data.edge_index.max().item()
        edge_index = new_data.edge_index

        if max_edge_index >= num_nodes:
            print(
                f"In file {filename}, edge_index max ({max_edge_index}) is greater than or equal to the number of nodes ({num_nodes})."
            )
            valid_edges_mask = (edge_index[0] < num_nodes) & (edge_index[1] < num_nodes)
            filtered_edge_index = edge_index[:, valid_edges_mask]
            new_data.edge_index = filtered_edge_index
            torch.save(new_data, filepath)
            print(f"The file {filename} has been fixed and saved.")
        else:
            correct_edge_index_count += 1

print(f"Correct edge_index count: {correct_edge_index_count}")
print(f"Incorrect edge_index count: {incorrect_edge_index_count}")
